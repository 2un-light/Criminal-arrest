# %%
import csv

f = open("범죄의 검거단서_전처리.csv")
crime = csv.reader(f)

for i in crime:
    print(i)
    
f.close()
# Out:
# ['범죄별', '검거단서별', '2016 년', '2017 년', '2018 년', '2019 년', '2020 년']
# ['합계', '현행범', '144508', '120745', '99386', '87093', '67099']
# ['합계', '피해자신고', '489374', '476766', '464272', '489041', '475063']
# ['합계', '고소', '210767', '196981', '211890', '213458', '210319']
# ['합계', '고발', '58917', '56751', '56821', '56086', '49212']
# ['합계', '자수', '15898', '15334', '15264', '13514', '13905']
# ['합계', '민간체포', '355', '281', '231', '311', '251']
# ['합계', '진정투서', '84453', '82823', '89341', '98354', '106349']
# ['합계', '타인신고', '112226', '110525', '120497', '126321', '133367']
# ['합계', '신문', '4150', '4307', '3491', '3118', '2834']
# ['합계', '불심검문', '225983', '177363', '103302', '79981', '59552']
# ['합계', '탐문정보', '79795', '72259', '60879', '58558', '49967']
# ['합계', '안면식별', '300', '237', '292', '256', '183']
# ['합계', '감식자료', '831', '799', '539', '772', '441']
# ['합계', '변사체', '551', '587', '601', '520', '470']
# ['합계', '범죄수법', '775', '818', '599', '554', '373']
# ['합계', '발자국', '77', '29', '23', '13', '6']
# ['합계', '검사지휘', '1862', '1513', '2241', '2390', '3234']
# ['합계', '타기관에서 이송', '3143', '982', '1270', '1702', '1425']
# ['합계', '범행도구등 발견', '250', '344', '161', '164', '136']
# ['합계', '장물', '751', '1031', '697', '402', '336']
# ['합계', '전과조회', '137', '75', '82', '122', '111']
# ['합계', '기타', '256267', '236413', '234527', '247174', '224795']
# ['형법범', '현행범', '121151', '103277', '83047', '72385', '55662']
# ['형법범', '피해자신고', '277470', '286056', '293534', '320321', '314183']
# ['형법범', '고소', '183721', '173442', '187343', '188374', '184773']
# ['형법범', '고발', '3886', '4183', '4738', '5423', '5893']
# ['형법범', '자수', '1386', '1436', '1544', '1526', '1752']
# ['형법범', '민간체포', '310', '252', '208', '280', '231']
# ['형법범', '진정투서', '70549', '69227', '75128', '83032', '91231']
# ['형법범', '타인신고', '22582', '22499', '25454', '27926', '25571']
# ['형법범', '신문', '798', '662', '638', '862', '699']
# ['형법범', '불심검문', '2125', '1767', '1288', '1053', '932']
# ['형법범', '탐문정보', '46696', '37922', '33807', '33335', '33377']
# ['형법범', '안면식별', '276', '227', '282', '245', '172']
# ['형법범', '감식자료', '759', '744', '503', '518', '397']
# ['형법범', '변사체', '515', '526', '551', '477', '442']
# ['형법범', '범죄수법', '700', '757', '523', '499', '270']
# ['형법범', '발자국', '72', '27', '22', '10', '4']
# ['형법범', '검사지휘', '1111', '954', '1517', '1678', '2476']
# ['형법범', '타기관에서 이송', '334', '333', '386', '607', '519']
# ['형법범', '범행도구등 발견', '184', '272', '115', '108', '87']
# ['형법범', '장물', '746', '1019', '695', '401', '336']
# ['형법범', '전과조회', '109', '47', '57', '83', '89']
# ['형법범', '기타', '53798', '47274', '46542', '52254', '48646']
# ['재산범죄', '계', '389937', '370121', '382437', '414793', '422267']
# ['재산범죄', '현행범', '23460', '20931', '18359', '17320', '14556']
# ['재산범죄', '피해자신고', '114981', '120588', '125812', '143438', '148808']
# ['재산범죄', '고소', '111509', '100950', '106186', '107189', '105477']
# ['재산범죄', '고발', '1919', '2227', '2407', '2761', '3145']
# ['재산범죄', '자수', '857', '966', '976', '900', '1156']
# ['재산범죄', '민간체포', '224', '182', '147', '155', '181']
# ['재산범죄', '진정투서', '65797', '64638', '71038', '79285', '86947']
# ['재산범죄', '타인신고', '4661', '3957', '4027', '5063', '4362']
# ['재산범죄', '신문', '588', '458', '473', '671', '552']
# ['재산범죄', '불심검문', '1388', '1009', '843', '637', '631']
# ['재산범죄', '탐문정보', '32182', '27248', '25221', '25217', '25956']
# ['재산범죄', '안면식별', '226', '204', '267', '226', '154']
# ['재산범죄', '감식자료', '633', '636', '395', '438', '334']
# ['재산범죄', '변사체', '13', '21', '24', '20', '49']
# ['재산범죄', '범죄수법', '636', '695', '481', '462', '241']
# ['재산범죄', '발자국', '69', '27', '21', '8', '2']
# ['재산범죄', '검사지휘', '664', '478', '836', '891', '1594']
# ['재산범죄', '타기관에서 이송', '203', '186', '200', '399', '338']
# ['재산범죄', '범행도구등 발견', '113', '178', '68', '84', '56']
# ['재산범죄', '장물', '745', '1017', '694', '401', '336']
# ['재산범죄', '전과조회', '100', '37', '47', '73', '81']
# ['재산범죄', '기타', '28969', '23488', '23915', '29155', '27311']
# ['절도', '계', '119010', '114263', '107208', '114203', '111656']
# ['절도', '현행범', '7386', '6484', '5313', '5242', '4653']
# ['절도', '피해자신고', '71284', '73830', '70606', '76223', '75585']
# ['절도', '고소', '2531', '2468', '2578', '2904', '3028']
# ['절도', '고발', '51', '46', '73', '73', '92']
# ['절도', '자수', '415', '520', '489', '460', '433']
# ['절도', '민간체포', '208', '158', '138', '136', '155']
# ['절도', '진정투서', '582', '533', '551', '566', '672']
# ['절도', '타인신고', '1808', '1980', '1702', '1866', '1901']
# ['절도', '신문', '453', '388', '318', '402', '307']
# ['절도', '불심검문', '925', '695', '528', '432', '445']
# ['절도', '탐문정보', '21288', '17801', '15983', '16598', '15887']
# ['절도', '안면식별', '198', '168', '216', '189', '115']
# ['절도', '감식자료', '534', '515', '298', '298', '184']
# ['절도', '변사체', '7', '4', '4', '6', '3']
# ['절도', '범죄수법', '579', '652', '453', '406', '190']
# ['절도', '발자국', '68', '24', '18', '6', '1']
# ['절도', '검사지휘', '34', '32', '45', '36', '40']
# ['절도', '타기관에서 이송', '81', '84', '72', '62', '60']
# ['절도', '범행도구등 발견', '80', '147', '46', '68', '39']
# ['절도', '장물', '417', '703', '457', '269', '227']
# ['절도', '전과조회', '20', '14', '19', '21', '21']
# ['절도', '기타', '10061', '7017', '7301', '7940', '7618']
# ['장물', '계', '2117', '1910', '928', '890', '587']
# ['장물', '현행범', '54', '22', '8', '68', '4']
# ['장물', '피해자신고', '315', '240', '143', '159', '113']
# ['장물', '고소', '60', '48', '52', '48', '54']
# ['장물', '고발', '2', '0', '0', '1', '3']
# ['장물', '자수', '2', '1', '4', '2', '1']
# ['장물', '민간체포', '2', '0', '0', '0', '1']
# ['장물', '진정투서', '5', '4', '5', '6', '5']
# ['장물', '타인신고', '31', '38', '33', '86', '15']
# ['장물', '신문', '8', '6', '9', '1', '0']
# ['장물', '불심검문', '47', '11', '11', '5', '4']
# ['장물', '탐문정보', '894', '945', '306', '192', '166']
# ['장물', '안면식별', '0', '0', '1', '0', '0']
# ['장물', '감식자료', '0', '0', '0', '0', '0']
# ['장물', '변사체', '0', '0', '0', '0', '0']
# ['장물', '범죄수법', '0', '1', '0', '0', '0']
# ['장물', '발자국', '0', '0', '0', '0', '0']
# ['장물', '검사지휘', '4', '0', '6', '2', '4']
# ['장물', '타기관에서 이송', '1', '1', '2', '2', '1']
# ['장물', '범행도구등 발견', '0', '3', '0', '0', '0']
# ['장물', '장물', '197', '190', '107', '63', '64']
# ['장물', '전과조회', '0', '0', '0', '0', '0']
# ['장물', '기타', '495', '400', '241', '255', '152']
# ['사기', '현행범', '7801', '7248', '6981', '6688', '5763']
# ['사기', '피해자신고', '19088', '20459', '26773', '34978', '39549']
# ['사기', '고소', '88196', '79924', '84168', '85372', '83940']
# ['사기', '고발', '798', '1135', '1040', '1337', '1513']
# ['사기', '자수', '242', '251', '266', '194', '459']
# ['사기', '민간체포', '6', '14', '5', '14', '20']
# ['사기', '진정투서', '63780', '62773', '69393', '77221', '85116']
# ['사기', '타인신고', '1567', '738', '807', '1472', '751']
# ['사기', '신문', '84', '30', '116', '244', '223']
# ['사기', '불심검문', '263', '157', '184', '119', '104']
# ['사기', '탐문정보', '6875', '5000', '5037', '5014', '6070']
# ['사기', '안면식별', '5', '10', '23', '17', '16']
# ['사기', '감식자료', '54', '77', '70', '109', '109']
# ['사기', '변사체', '6', '16', '18', '10', '43']
# ['사기', '범죄수법', '49', '31', '23', '45', '43']
# ['사기', '발자국', '0', '1', '1', '2', '0']
# ['사기', '검사지휘', '512', '370', '648', '695', '1314']
# ['사기', '타기관에서 이송', '101', '80', '103', '312', '252']
# ['사기', '범행도구등 발견', '26', '9', '2', '6', '6']
# ['사기', '장물', '3', '5', '3', '0', '2']
# ['사기', '전과조회', '76', '20', '24', '51', '57']
# ['사기', '기타', '13704', '11912', '12242', '16712', '15783']
# ['횡령', '현행범', '337', '270', '274', '299', '248']
# ['횡령', '피해자신고', '6171', '7165', '8209', '9177', '9886']
# ['횡령', '고소', '14525', '12645', '12804', '12568', '12197']
# ['횡령', '고발', '690', '654', '795', '833', '872']
# ['횡령', '자수', '91', '99', '101', '99', '120']
# ['횡령', '민간체포', '3', '3', '2', '0', '3']
# ['횡령', '진정투서', '992', '875', '643', '619', '680']
# ['횡령', '타인신고', '360', '337', '362', '314', '348']
# ['횡령', '신문', '18', '16', '19', '8', '9']
# ['횡령', '불심검문', '134', '129', '109', '74', '60']
# ['횡령', '탐문정보', '1988', '2365', '2722', '2178', '2486']
# ['횡령', '안면식별', '13', '11', '16', '12', '11']
# ['횡령', '감식자료', '5', '6', '2', '8', '22']
# ['횡령', '변사체', '0', '0', '1', '2', '2']
# ['횡령', '범죄수법', '3', '8', '5', '4', '6']
# ['횡령', '발자국', '0', '0', '0', '0', '0']
# ['횡령', '검사지휘', '77', '45', '81', '85', '153']
# ['횡령', '타기관에서 이송', '14', '13', '16', '16', '20']
# ['횡령', '범행도구등 발견', '6', '14', '14', '6', '6']
# ['횡령', '장물', '128', '118', '127', '69', '43']
# ['횡령', '전과조회', '3', '2', '3', '1', '2']
# ['횡령', '기타', '2365', '2297', '2205', '2264', '1846']
# ['배임', '현행범', '3', '2', '0', '0', '2']
# ['배임', '피해자신고', '24', '23', '13', '16', '20']
# ['배임', '고소', '3018', '2696', '3254', '2946', '2799']
# ['배임', '고발', '304', '320', '444', '448', '572']
# ['배임', '자수', '3', '1', '1', '7', '3']
# ['배임', '민간체포', '0', '0', '0', '0', '0']
# ['배임', '진정투서', '59', '53', '53', '511', '33']
# ['배임', '타인신고', '6', '7', '11', '7', '6']
# ['배임', '신문', '8', '9', '2', '6', '0']
# ['배임', '불심검문', '1', '3', '1', '0', '0']
# ['배임', '탐문정보', '208', '184', '129', '100', '71']
# ['배임', '안면식별', '0', '0', '0', '0', '0']
# ['배임', '감식자료', '0', '0', '0', '0', '0']
# ['배임', '변사체', '0', '0', '0', '0', '0']
# ['배임', '범죄수법', '0', '1', '0', '0', '0']
# ['배임', '발자국', '0', '0', '0', '0', '0']
# ['배임', '검사지휘', '18', '15', '31', '38', '41']
# ['배임', '타기관에서 이송', '1', '4', '1', '2', '3']
# ['배임', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['배임', '장물', '0', '1', '0', '0', '0']
# ['배임', '전과조회', '0', '0', '0', '0', '0']
# ['배임', '기타', '1372', '998', '956', '924', '674']
# ['손괴', '현행범', '7879', '6905', '5783', '5023', '3886']
# ['손괴', '피해자신고', '18099', '18871', '20068', '22885', '23655']
# ['손괴', '고소', '3179', '3169', '3330', '3351', '3459']
# ['손괴', '고발', '74', '72', '55', '69', '93']
# ['손괴', '자수', '104', '94', '115', '138', '140']
# ['손괴', '민간체포', '5', '7', '2', '5', '2']
# ['손괴', '진정투서', '379', '400', '393', '362', '441']
# ['손괴', '타인신고', '889', '857', '1112', '1318', '1341']
# ['손괴', '신문', '17', '9', '9', '10', '13']
# ['손괴', '불심검문', '18', '14', '10', '7', '18']
# ['손괴', '탐문정보', '929', '953', '1044', '1135', '1276']
# ['손괴', '안면식별', '10', '15', '11', '8', '12']
# ['손괴', '감식자료', '40', '38', '25', '23', '19']
# ['손괴', '변사체', '0', '1', '1', '2', '1']
# ['손괴', '범죄수법', '5', '2', '0', '7', '2']
# ['손괴', '발자국', '1', '2', '2', '0', '1']
# ['손괴', '검사지휘', '19', '16', '25', '35', '42']
# ['손괴', '타기관에서 이송', '5', '4', '6', '5', '2']
# ['손괴', '범행도구등 발견', '1', '5', '6', '4', '5']
# ['손괴', '장물', '0', '0', '0', '0', '0']
# ['손괴', '전과조회', '1', '1', '1', '0', '1']
# ['손괴', '기타', '972', '864', '970', '1060', '1238']
# ['강력범죄(흉악)', '현행범', '5784', '6130', '4215', '3412', '2257']
# ['강력범죄(흉악)', '피해자신고', '14492', '16059', '15249', '15375', '13834']
# ['강력범죄(흉악)', '고소', '3988', '4916', '7047', '7601', '9000']
# ['강력범죄(흉악)', '고발', '61', '115', '155', '122', '120']
# ['강력범죄(흉악)', '자수', '110', '97', '142', '141', '120']
# ['강력범죄(흉악)', '민간체포', '59', '50', '45', '95', '35']
# ['강력범죄(흉악)', '진정투서', '343', '458', '502', '496', '654']
# ['강력범죄(흉악)', '타인신고', '1951', '2463', '2572', '2877', '2474']
# ['강력범죄(흉악)', '신문', '38', '29', '14', '22', '45']
# ['강력범죄(흉악)', '불심검문', '244', '229', '185', '232', '139']
# ['강력범죄(흉악)', '탐문정보', '2730', '2142', '1421', '1009', '767']
# ['강력범죄(흉악)', '안면식별', '13', '8', '6', '6', '3']
# ['강력범죄(흉악)', '감식자료', '55', '46', '55', '32', '28']
# ['강력범죄(흉악)', '변사체', '94', '79', '87', '96', '77']
# ['강력범죄(흉악)', '범죄수법', '16', '3', '11', '25', '17']
# ['강력범죄(흉악)', '발자국', '0', '0', '0', '1', '2']
# ['강력범죄(흉악)', '검사지휘', '37', '33', '96', '78', '79']
# ['강력범죄(흉악)', '타기관에서 이송', '7', '26', '15', '31', '25']
# ['강력범죄(흉악)', '범행도구등 발견', '55', '72', '38', '12', '15']
# ['강력범죄(흉악)', '장물', '0', '0', '0', '0', '0']
# ['강력범죄(흉악)', '전과조회', '0', '1', '1', '0', '1']
# ['강력범죄(흉악)', '기타', '1591', '1695', '1838', '1774', '1498']
# ['살인', '현행범', '264', '251', '232', '202', '176']
# ['살인', '피해자신고', '128', '139', '110', '104', '125']
# ['살인', '고소', '37', '35', '55', '62', '51']
# ['살인', '고발', '1', '1', '7', '5', '8']
# ['살인', '자수', '41', '36', '35', '35', '36']
# ['살인', '민간체포', '1', '1', '2', '1', '0']
# ['살인', '진정투서', '1', '1', '0', '3', '0']
# ['살인', '타인신고', '205', '199', '182', '194', '165']
# ['살인', '신문', '1', '3', '2', '1', '0']
# ['살인', '불심검문', '1', '2', '2', '3', '0']
# ['살인', '탐문정보', '68', '41', '40', '35', '22']
# ['살인', '안면식별', '1', '0', '2', '2', '0']
# ['살인', '감식자료', '0', '1', '0', '0', '2']
# ['살인', '변사체', '76', '62', '68', '80', '64']
# ['살인', '범죄수법', '0', '0', '0', '0', '0']
# ['살인', '발자국', '0', '0', '0', '1', '1']
# ['살인', '검사지휘', '2', '2', '3', '3', '1']
# ['살인', '타기관에서 이송', '0', '0', '2', '0', '0']
# ['살인', '범행도구등 발견', '7', '2', '2', '1', '6']
# ['살인', '장물', '0', '0', '0', '0', '0']
# ['살인', '전과조회', '0', '0', '0', '0', '0']
# ['살인', '기타', '102', '71', '64', '91', '90']
# ['강도', '현행범', '157', '144', '108', '84', '74']
# ['강도', '피해자신고', '588', '488', '434', '408', '332']
# ['강도', '고소', '38', '40', '38', '45', '61']
# ['강도', '고발', '1', '1', '0', '1', '2']
# ['강도', '자수', '6', '6', '6', '2', '4']
# ['강도', '민간체포', '3', '0', '2', '1', '4']
# ['강도', '진정투서', '3', '2', '2', '5', '10']
# ['강도', '타인신고', '59', '44', '27', '39', '31']
# ['강도', '신문', '2', '1', '4', '1', '9']
# ['강도', '불심검문', '7', '1', '2', '7', '3']
# ['강도', '탐문정보', '205', '172', '132', '123', '93']
# ['강도', '안면식별', '2', '0', '2', '2', '1']
# ['강도', '감식자료', '19', '13', '8', '5', '5']
# ['강도', '변사체', '5', '5', '3', '7', '3']
# ['강도', '범죄수법', '3', '1', '2', '13', '0']
# ['강도', '발자국', '0', '0', '0', '0', '0']
# ['강도', '검사지휘', '2', '0', '0', '3', '0']
# ['강도', '타기관에서 이송', '1', '1', '2', '1', '0']
# ['강도', '범행도구등 발견', '6', '1', '1', '0', '0']
# ['강도', '장물', '0', '0', '0', '0', '0']
# ['강도', '전과조회', '0', '0', '0', '0', '0']
# ['강도', '기타', '88', '73', '57', '96', '41']
# ['방화', '현행범', '442', '382', '433', '388', '314']
# ['방화', '피해자신고', '468', '430', '452', '392', '409']
# ['방화', '고소', '10', '10', '10', '12', '11']
# ['방화', '고발', '0', '0', '3', '3', '0']
# ['방화', '자수', '19', '16', '28', '25', '12']
# ['방화', '민간체포', '1', '0', '1', '2', '1']
# ['방화', '진정투서', '1', '0', '2', '1', '3']
# ['방화', '타인신고', '211', '217', '227', '238', '216']
# ['방화', '신문', '3', '4', '1', '2', '0']
# ['방화', '불심검문', '3', '3', '1', '2', '5']
# ['방화', '탐문정보', '71', '81', '72', '74', '46']
# ['방화', '안면식별', '6', '3', '1', '0', '0']
# ['방화', '감식자료', '3', '4', '2', '4', '5']
# ['방화', '변사체', '4', '5', '4', '5', '6']
# ['방화', '범죄수법', '0', '0', '2', '2', '3']
# ['방화', '발자국', '0', '0', '0', '0', '0']
# ['방화', '검사지휘', '1', '0', '0', '0', '1']
# ['방화', '타기관에서 이송', '0', '3', '2', '0', '0']
# ['방화', '범행도구등 발견', '1', '3', '3', '1', '1']
# ['방화', '장물', '0', '0', '0', '0', '0']
# ['방화', '전과조회', '0', '0', '0', '0', '0']
# ['방화', '기타', '96', '65', '106', '70', '62']
# ['성폭력', '현행범', '4921', '5353', '3442', '2738', '1693']
# ['성폭력', '피해자신고', '13308', '15002', '14253', '14471', '12968']
# ['성폭력', '고소', '3903', '4831', '6944', '7482', '8877']
# ['성폭력', '고발', '59', '113', '145', '113', '110']
# ['성폭력', '자수', '44', '39', '73', '79', '68']
# ['성폭력', '민간체포', '54', '49', '40', '91', '30']
# ['성폭력', '진정투서', '338', '455', '498', '487', '641']
# ['성폭력', '타인신고', '1476', '2003', '2136', '2406', '2062']
# ['성폭력', '신문', '32', '21', '7', '18', '36']
# ['성폭력', '불심검문', '233', '223', '180', '220', '131']
# ['성폭력', '탐문정보', '2386', '1848', '1177', '777', '606']
# ['성폭력', '안면식별', '4', '5', '1', '2', '2']
# ['성폭력', '감식자료', '33', '28', '45', '23', '16']
# ['성폭력', '변사체', '9', '7', '12', '4', '4']
# ['성폭력', '범죄수법', '13', '2', '7', '10', '14']
# ['성폭력', '발자국', '0', '0', '0', '0', '1']
# ['성폭력', '검사지휘', '32', '31', '93', '72', '77']
# ['성폭력', '타기관에서 이송', '6', '22', '9', '30', '25']
# ['성폭력', '범행도구등 발견', '41', '66', '32', '10', '8']
# ['성폭력', '장물', '0', '0', '0', '0', '0']
# ['성폭력', '전과조회', '0', '1', '1', '0', '1']
# ['성폭력', '기타', '1305', '1486', '1611', '1517', '1305']
# ['강력범죄(폭력)', '현행범', '61733', '49974', '37400', '30481', '20724']
# ['강력범죄(폭력)', '피해자신고', '131081', '131788', '133340', '138777', '127599']
# ['강력범죄(폭력)', '고소', '22512', '22160', '24713', '23852', '23113']
# ['강력범죄(폭력)', '고발', '132', '115', '153', '157', '202']
# ['강력범죄(폭력)', '자수', '243', '217', '302', '319', '311']
# ['강력범죄(폭력)', '민간체포', '6', '7', '7', '15', '5']
# ['강력범죄(폭력)', '진정투서', '1931', '2040', '1841', '1635', '1862']
# ['강력범죄(폭력)', '타인신고', '10325', '10392', '13199', '14006', '12949']
# ['강력범죄(폭력)', '신문', '61', '48', '43', '40', '40']
# ['강력범죄(폭력)', '불심검문', '122', '81', '49', '42', '38']
# ['강력범죄(폭력)', '탐문정보', '4038', '3346', '2407', '2265', '2349']
# ['강력범죄(폭력)', '안면식별', '13', '12', '3', '7', '10']
# ['강력범죄(폭력)', '감식자료', '25', '24', '16', '12', '7']
# ['강력범죄(폭력)', '변사체', '39', '38', '41', '45', '40']
# ['강력범죄(폭력)', '범죄수법', '2', '19', '14', '2', '0']
# ['강력범죄(폭력)', '발자국', '1', '0', '0', '0', '0']
# ['강력범죄(폭력)', '검사지휘', '109', '128', '159', '193', '185']
# ['강력범죄(폭력)', '타기관에서 이송', '55', '61', '81', '77', '58']
# ['강력범죄(폭력)', '범행도구등 발견', '3', '8', '1', '5', '5']
# ['강력범죄(폭력)', '장물', '0', '0', '1', '0', '0']
# ['강력범죄(폭력)', '전과조회', '3', '6', '3', '6', '4']
# ['강력범죄(폭력)', '기타', '7397', '6581', '7079', '7723', '7888']
# ['폭행', '현행범', '47724', '39100', '28811', '22722', '14920']
# ['폭행', '피해자신고', '93998', '96363', '100598', '103987', '94981']
# ['폭행', '고소', '8175', '8930', '10793', '10682', '10135']
# ['폭행', '고발', '38', '44', '48', '68', '79']
# ['폭행', '자수', '117', '130', '179', '207', '186']
# ['폭행', '민간체포', '3', '6', '5', '6', '3']
# ['폭행', '진정투서', '764', '880', '897', '723', '846']
# ['폭행', '타인신고', '6525', '6643', '9025', '9342', '8682']
# ['폭행', '신문', '41', '36', '26', '27', '28']
# ['폭행', '불심검문', '56', '31', '21', '16', '12']
# ['폭행', '탐문정보', '1323', '1226', '1154', '1095', '1273']
# ['폭행', '안면식별', '5', '8', '1', '2', '4']
# ['폭행', '감식자료', '13', '15', '11', '8', '4']
# ['폭행', '변사체', '22', '18', '27', '25', '24']
# ['폭행', '범죄수법', '1', '1', '0', '0', '0']
# ['폭행', '발자국', '0', '0', '0', '0', '0']
# ['폭행', '검사지휘', '28', '41', '53', '78', '63']
# ['폭행', '타기관에서 이송', '27', '30', '48', '40', '34']
# ['폭행', '범행도구등 발견', '1', '1', '0', '2', '0']
# ['폭행', '장물', '0', '0', '1', '0', '0']
# ['폭행', '전과조회', '2', '2', '2', '4', '3']
# ['폭행', '기타', '4504', '3944', '4469', '4768', '4997']
# ['상해', '현행범', '10141', '7634', '5513', '4508', '3185']
# ['상해', '피해자신고', '27379', '25285', '22224', '21195', '19201']
# ['상해', '고소', '9891', '8899', '8591', '7451', '6865']
# ['상해', '고발', '33', '26', '34', '25', '33']
# ['상해', '자수', '97', '65', '98', '81', '94']
# ['상해', '민간체포', '2', '1', '1', '4', '2']
# ['상해', '진정투서', '603', '516', '424', '318', '322']
# ['상해', '타인신고', '3260', '3116', '3453', '3655', '3282']
# ['상해', '신문', '15', '8', '9', '7', '7']
# ['상해', '불심검문', '44', '29', '11', '4', '9']
# ['상해', '탐문정보', '1043', '803', '559', '492', '445']
# ['상해', '안면식별', '6', '2', '1', '0', '1']
# ['상해', '감식자료', '5', '3', '2', '3', '1']
# ['상해', '변사체', '16', '20', '12', '19', '13']
# ['상해', '범죄수법', '0', '1', '1', '0', '0']
# ['상해', '발자국', '1', '0', '0', '0', '0']
# ['상해', '검사지휘', '35', '39', '53', '49', '44']
# ['상해', '타기관에서 이송', '15', '21', '24', '21', '13']
# ['상해', '범행도구등 발견', '0', '2', '1', '1', '4']
# ['상해', '장물', '0', '0', '0', '0', '0']
# ['상해', '전과조회', '1', '3', '0', '2', '0']
# ['상해', '기타', '1674', '1558', '1436', '1440', '1461']
# ['협박', '현행범', '3284', '2746', '2748', '2951', '2375']
# ['협박', '피해자신고', '7426', '7727', '8355', '11154', '11233']
# ['협박', '고소', '3012', '2925', '3712', '3943', '4267']
# ['협박', '고발', '18', '16', '27', '22', '26']
# ['협박', '자수', '21', '14', '19', '20', '21']
# ['협박', '민간체포', '1', '0', '1', '2', '0']
# ['협박', '진정투서', '334', '317', '291', '289', '347']
# ['협박', '타인신고', '318', '358', '466', '715', '746']
# ['협박', '신문', '2', '2', '1', '4', '4']
# ['협박', '불심검문', '13', '16', '16', '20', '15']
# ['협박', '탐문정보', '382', '281', '195', '182', '180']
# ['협박', '안면식별', '0', '0', '0', '0', '0']
# ['협박', '감식자료', '2', '0', '0', '0', '1']
# ['협박', '변사체', '1', '0', '1', '1', '2']
# ['협박', '범죄수법', '0', '0', '1', '0', '0']
# ['협박', '발자국', '0', '0', '0', '0', '0']
# ['협박', '검사지휘', '22', '26', '33', '44', '38']
# ['협박', '타기관에서 이송', '8', '4', '7', '5', '8']
# ['협박', '범행도구등 발견', '2', '4', '0', '2', '1']
# ['협박', '장물', '0', '0', '0', '0', '0']
# ['협박', '전과조회', '0', '0', '1', '0', '0']
# ['협박', '기타', '650', '627', '696', '917', '990']
# ['공갈', '현행범', '183', '103', '68', '76', '43']
# ['공갈', '피해자신고', '1223', '1189', '1121', '1206', '1028']
# ['공갈', '고소', '838', '866', '1071', '1191', '1131']
# ['공갈', '고발', '23', '18', '23', '14', '37']
# ['공갈', '자수', '2', '4', '1', '3', '2']
# ['공갈', '민간체포', '0', '0', '0', '0', '0']
# ['공갈', '진정투서', '195', '303', '194', '280', '317']
# ['공갈', '타인신고', '47', '80', '59', '80', '67']
# ['공갈', '신문', '2', '2', '4', '0', '0']
# ['공갈', '불심검문', '5', '3', '0', '2', '2']
# ['공갈', '탐문정보', '1093', '867', '356', '371', '373']
# ['공갈', '안면식별', '1', '1', '0', '1', '3']
# ['공갈', '감식자료', '1', '4', '0', '0', '0']
# ['공갈', '변사체', '0', '0', '1', '0', '1']
# ['공갈', '범죄수법', '1', '17', '12', '2', '0']
# ['공갈', '발자국', '0', '0', '0', '0', '0']
# ['공갈', '검사지휘', '17', '8', '13', '19', '25']
# ['공갈', '타기관에서 이송', '3', '4', '1', '8', '2']
# ['공갈', '범행도구등 발견', '0', '1', '0', '0', '0']
# ['공갈', '장물', '0', '0', '0', '0', '0']
# ['공갈', '전과조회', '0', '1', '0', '0', '1']
# ['공갈', '기타', '373', '277', '308', '401', '252']
# ['약취와유인', '현행범', '20', '15', '12', '10', '6']
# ['약취와유인', '피해자신고', '73', '82', '72', '95', '71']
# ['약취와유인', '고소', '34', '46', '32', '57', '55']
# ['약취와유인', '고발', '1', '1', '3', '1', '4']
# ['약취와유인', '자수', '1', '0', '1', '1', '0']
# ['약취와유인', '민간체포', '0', '0', '0', '0', '0']
# ['약취와유인', '진정투서', '1', '4', '2', '0', '2']
# ['약취와유인', '타인신고', '14', '24', '20', '33', '32']
# ['약취와유인', '신문', '0', '0', '0', '0', '0']
# ['약취와유인', '불심검문', '1', '0', '0', '0', '0']
# ['약취와유인', '탐문정보', '19', '9', '17', '13', '5']
# ['약취와유인', '안면식별', '1', '0', '0', '0', '0']
# ['약취와유인', '감식자료', '0', '0', '0', '0', '0']
# ['약취와유인', '변사체', '0', '0', '0', '0', '0']
# ['약취와유인', '범죄수법', '0', '0', '0', '0', '0']
# ['약취와유인', '발자국', '0', '0', '0', '0', '0']
# ['약취와유인', '검사지휘', '0', '1', '0', '1', '1']
# ['약취와유인', '타기관에서 이송', '1', '0', '0', '1', '0']
# ['약취와유인', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['약취와유인', '장물', '0', '0', '0', '0', '0']
# ['약취와유인', '전과조회', '0', '0', '0', '0', '0']
# ['약취와유인', '기타', '27', '17', '15', '20', '19']
# ['체포와감금', '현행범', '251', '277', '187', '157', '138']
# ['체포와감금', '피해자신고', '615', '754', '617', '705', '603']
# ['체포와감금', '고소', '319', '286', '294', '276', '351']
# ['체포와감금', '고발', '15', '7', '15', '16', '9']
# ['체포와감금', '자수', '2', '1', '1', '1', '1']
# ['체포와감금', '민간체포', '0', '0', '0', '0', '0']
# ['체포와감금', '진정투서', '17', '7', '17', '13', '13']
# ['체포와감금', '타인신고', '136', '152', '139', '149', '117']
# ['체포와감금', '신문', '1', '0', '1', '0', '0']
# ['체포와감금', '불심검문', '1', '2', '1', '0', '0']
# ['체포와감금', '탐문정보', '43', '49', '33', '27', '20']
# ['체포와감금', '안면식별', '0', '0', '0', '0', '1']
# ['체포와감금', '감식자료', '0', '0', '0', '0', '0']
# ['체포와감금', '변사체', '0', '0', '0', '0', '0']
# ['체포와감금', '범죄수법', '0', '0', '0', '0', '0']
# ['체포와감금', '발자국', '0', '0', '0', '0', '0']
# ['체포와감금', '검사지휘', '5', '10', '3', '2', '9']
# ['체포와감금', '타기관에서 이송', '1', '1', '1', '1', '0']
# ['체포와감금', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['체포와감금', '장물', '0', '0', '0', '0', '0']
# ['체포와감금', '전과조회', '0', '0', '0', '0', '0']
# ['체포와감금', '기타', '76', '97', '78', '107', '93']
# ['폭력행위등(손괴,강요,주거침입등)', '현행범', '105', '92', '47', '51', '54']
# ['폭력행위등(손괴,강요,주거침입등)', '피해자신고', '323', '373', '322', '401', '455']
# ['폭력행위등(손괴,강요,주거침입등)', '고소', '234', '202', '211', '231', '294']
# ['폭력행위등(손괴,강요,주거침입등)', '고발', '4', '3', '3', '10', '14']
# ['폭력행위등(손괴,강요,주거침입등)', '자수', '3', '1', '0', '2', '0']
# ['폭력행위등(손괴,강요,주거침입등)', '민간체포', '0', '0', '0', '3', '0']
# ['폭력행위등(손괴,강요,주거침입등)', '진정투서', '15', '13', '15', '12', '14']
# ['폭력행위등(손괴,강요,주거침입등)', '타인신고', '19', '14', '25', '22', '20']
# ['폭력행위등(손괴,강요,주거침입등)', '신문', '0', '0', '1', '0', '1']
# ['폭력행위등(손괴,강요,주거침입등)', '불심검문', '1', '0', '0', '0', '0']
# ['폭력행위등(손괴,강요,주거침입등)', '탐문정보', '52', '38', '30', '25', '15']
# ['폭력행위등(손괴,강요,주거침입등)', '안면식별', '0', '1', '0', '2', '1']
# ['폭력행위등(손괴,강요,주거침입등)', '감식자료', '4', '2', '2', '1', '1']
# ['폭력행위등(손괴,강요,주거침입등)', '변사체', '0', '0', '0', '0', '0']
# ['폭력행위등(손괴,강요,주거침입등)', '범죄수법', '0', '0', '0', '0', '0']
# ['폭력행위등(손괴,강요,주거침입등)', '발자국', '0', '0', '0', '0', '0']
# ['폭력행위등(손괴,강요,주거침입등)', '검사지휘', '2', '3', '4', '0', '4']
# ['폭력행위등(손괴,강요,주거침입등)', '타기관에서 이송', '0', '1', '0', '0', '0']
# ['폭력행위등(손괴,강요,주거침입등)', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['폭력행위등(손괴,강요,주거침입등)', '장물', '0', '0', '0', '0', '0']
# ['폭력행위등(손괴,강요,주거침입등)', '전과조회', '0', '0', '0', '0', '0']
# ['폭력행위등(손괴,강요,주거침입등)', '기타', '73', '40', '51', '50', '44']
# ['폭력행위등(단체등의구성·활동)', '현행범', '25', '7', '14', '6', '3']
# ['폭력행위등(단체등의구성·활동)', '피해자신고', '44', '15', '31', '34', '27']
# ['폭력행위등(단체등의구성·활동)', '고소', '9', '6', '9', '21', '15']
# ['폭력행위등(단체등의구성·활동)', '고발', '0', '0', '0', '1', '0']
# ['폭력행위등(단체등의구성·활동)', '자수', '0', '2', '3', '4', '7']
# ['폭력행위등(단체등의구성·활동)', '민간체포', '0', '0', '0', '0', '0']
# ['폭력행위등(단체등의구성·활동)', '진정투서', '2', '0', '1', '0', '1']
# ['폭력행위등(단체등의구성·활동)', '타인신고', '6', '5', '12', '10', '3']
# ['폭력행위등(단체등의구성·활동)', '신문', '0', '0', '1', '2', '0']
# ['폭력행위등(단체등의구성·활동)', '불심검문', '1', '0', '0', '0', '0']
# ['폭력행위등(단체등의구성·활동)', '탐문정보', '83', '73', '63', '60', '38']
# ['폭력행위등(단체등의구성·활동)', '안면식별', '0', '0', '1', '2', '0']
# ['폭력행위등(단체등의구성·활동)', '감식자료', '0', '0', '1', '0', '0']
# ['폭력행위등(단체등의구성·활동)', '변사체', '0', '0', '0', '0', '0']
# ['폭력행위등(단체등의구성·활동)', '범죄수법', '0', '0', '0', '0', '0']
# ['폭력행위등(단체등의구성·활동)', '발자국', '0', '0', '0', '0', '0']
# ['폭력행위등(단체등의구성·활동)', '검사지휘', '0', '0', '0', '0', '1']
# ['폭력행위등(단체등의구성·활동)', '타기관에서 이송', '0', '0', '0', '1', '1']
# ['폭력행위등(단체등의구성·활동)', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['폭력행위등(단체등의구성·활동)', '장물', '0', '0', '0', '0', '0']
# ['폭력행위등(단체등의구성·활동)', '전과조회', '0', '0', '0', '0', '0']
# ['폭력행위등(단체등의구성·활동)', '기타', '20', '21', '26', '20', '32']
# ['위조범죄', '현행범', '248', '173', '121', '115', '64']
# ['위조범죄', '피해자신고', '359', '565', '336', '288', '265']
# ['위조범죄', '고소', '6749', '5986', '6005', '6138', '5881']
# ['위조범죄', '고발', '1011', '921', '1003', '1115', '1088']
# ['위조범죄', '자수', '20', '12', '15', '17', '20']
# ['위조범죄', '민간체포', '2', '2', '0', '1', '0']
# ['위조범죄', '진정투서', '1142', '752', '624', '557', '530']
# ['위조범죄', '타인신고', '896', '958', '786', '796', '731']
# ['위조범죄', '신문', '36', '35', '25', '41', '27']
# ['위조범죄', '불심검문', '235', '343', '147', '92', '87']
# ['위조범죄', '탐문정보', '326', '1213', '1457', '372', '150']
# ['위조범죄', '안면식별', '0', '0', '0', '1', '0']
# ['위조범죄', '감식자료', '2', '2', '4', '3', '0']
# ['위조범죄', '변사체', '0', '0', '0', '0', '0']
# ['위조범죄', '범죄수법', '24', '29', '6', '8', '5']
# ['위조범죄', '발자국', '0', '0', '0', '0', '0']
# ['위조범죄', '검사지휘', '46', '41', '71', '71', '92']
# ['위조범죄', '타기관에서 이송', '13', '17', '14', '23', '21']
# ['위조범죄', '범행도구등 발견', '4', '5', '2', '0', '0']
# ['위조범죄', '장물', '0', '0', '0', '0', '0']
# ['위조범죄', '전과조회', '3', '1', '0', '2', '1']
# ['위조범죄', '기타', '2962', '3434', '3456', '3328', '2658']
# ['통화', '현행범', '6', '9', '3', '3', '1']
# ['통화', '피해자신고', '46', '313', '88', '46', '17']
# ['통화', '고소', '0', '2', '0', '1', '0']
# ['통화', '고발', '8', '7', '7', '1', '1']
# ['통화', '자수', '2', '0', '0', '2', '0']
# ['통화', '민간체포', '0', '0', '0', '0', '0']
# ['통화', '진정투서', '3', '10', '9', '3', '6']
# ['통화', '타인신고', '18', '31', '31', '15', '30']
# ['통화', '신문', '0', '0', '1', '0', '0']
# ['통화', '불심검문', '0', '2', '0', '4', '0']
# ['통화', '탐문정보', '21', '8', '2', '18', '1']
# ['통화', '안면식별', '0', '0', '0', '0', '0']
# ['통화', '감식자료', '1', '0', '1', '0', '0']
# ['통화', '변사체', '0', '0', '0', '0', '0']
# ['통화', '범죄수법', '0', '1', '0', '1', '1']
# ['통화', '발자국', '0', '0', '0', '0', '0']
# ['통화', '검사지휘', '0', '0', '0', '2', '0']
# ['통화', '타기관에서 이송', '0', '0', '0', '0', '0']
# ['통화', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['통화', '장물', '0', '0', '0', '0', '0']
# ['통화', '전과조회', '0', '0', '0', '0', '0']
# ['통화', '기타', '18', '150', '17', '48', '8']
# ['유가증권·인지·우표', '현행범', '1', '4', '3', '0', '1']
# ['유가증권·인지·우표', '피해자신고', '5', '15', '17', '11', '12']
# ['유가증권·인지·우표', '고소', '145', '129', '68', '71', '41']
# ['유가증권·인지·우표', '고발', '8', '6', '42', '2', '6']
# ['유가증권·인지·우표', '자수', '0', '0', '0', '0', '0']
# ['유가증권·인지·우표', '민간체포', '0', '1', '0', '0', '0']
# ['유가증권·인지·우표', '진정투서', '2', '3', '0', '1', '0']
# ['유가증권·인지·우표', '타인신고', '5', '4', '4', '5', '3']
# ['유가증권·인지·우표', '신문', '0', '0', '0', '0', '0']
# ['유가증권·인지·우표', '불심검문', '0', '0', '0', '0', '0']
# ['유가증권·인지·우표', '탐문정보', '6', '6', '6', '5', '1']
# ['유가증권·인지·우표', '안면식별', '0', '0', '0', '0', '0']
# ['유가증권·인지·우표', '감식자료', '0', '1', '0', '1', '0']
# ['유가증권·인지·우표', '변사체', '0', '0', '0', '0', '0']
# ['유가증권·인지·우표', '범죄수법', '7', '0', '0', '0', '0']
# ['유가증권·인지·우표', '발자국', '0', '0', '0', '0', '0']
# ['유가증권·인지·우표', '검사지휘', '1', '0', '1', '0', '0']
# ['유가증권·인지·우표', '타기관에서 이송', '0', '0', '0', '0', '0']
# ['유가증권·인지·우표', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['유가증권·인지·우표', '장물', '0', '0', '0', '0', '0']
# ['유가증권·인지·우표', '전과조회', '0', '0', '0', '0', '0']
# ['유가증권·인지·우표', '기타', '61', '57', '44', '45', '19']
# ['문서', '현행범', '174', '115', '85', '82', '49']
# ['문서', '피해자신고', '294', '227', '227', '216', '226']
# ['문서', '고소', '6531', '5760', '5847', '5959', '5731']
# ['문서', '고발', '956', '872', '936', '1091', '1055']
# ['문서', '자수', '17', '12', '13', '14', '17']
# ['문서', '민간체포', '2', '1', '0', '1', '0']
# ['문서', '진정투서', '1115', '725', '601', '539', '507']
# ['문서', '타인신고', '825', '714', '704', '715', '636']
# ['문서', '신문', '29', '34', '23', '38', '26']
# ['문서', '불심검문', '82', '55', '21', '33', '16']
# ['문서', '탐문정보', '275', '1182', '812', '337', '135']
# ['문서', '안면식별', '0', '0', '0', '1', '0']
# ['문서', '감식자료', '0', '1', '2', '2', '0']
# ['문서', '변사체', '0', '0', '0', '0', '0']
# ['문서', '범죄수법', '17', '28', '6', '7', '4']
# ['문서', '발자국', '0', '0', '0', '0', '0']
# ['문서', '검사지휘', '42', '40', '69', '68', '90']
# ['문서', '타기관에서 이송', '13', '17', '13', '23', '20']
# ['문서', '범행도구등 발견', '1', '4', '2', '0', '0']
# ['문서', '장물', '0', '0', '0', '0', '0']
# ['문서', '전과조회', '2', '0', '0', '2', '1']
# ['문서', '기타', '2656', '3023', '3239', '3108', '2523']
# ['인장', '현행범', '67', '45', '30', '30', '13']
# ['인장', '피해자신고', '14', '10', '4', '15', '10']
# ['인장', '고소', '73', '95', '90', '107', '109']
# ['인장', '고발', '39', '36', '18', '21', '26']
# ['인장', '자수', '1', '0', '2', '1', '3']
# ['인장', '민간체포', '0', '0', '0', '0', '0']
# ['인장', '진정투서', '22', '14', '14', '14', '17']
# ['인장', '타인신고', '48', '209', '47', '61', '62']
# ['인장', '신문', '7', '1', '1', '3', '1']
# ['인장', '불심검문', '153', '286', '126', '55', '71']
# ['인장', '탐문정보', '24', '17', '637', '12', '13']
# ['인장', '안면식별', '0', '0', '0', '0', '0']
# ['인장', '감식자료', '1', '0', '1', '0', '0']
# ['인장', '변사체', '0', '0', '0', '0', '0']
# ['인장', '범죄수법', '0', '0', '0', '0', '0']
# ['인장', '발자국', '0', '0', '0', '0', '0']
# ['인장', '검사지휘', '3', '1', '1', '1', '2']
# ['인장', '타기관에서 이송', '0', '0', '1', '0', '1']
# ['인장', '범행도구등 발견', '3', '1', '0', '0', '0']
# ['인장', '장물', '0', '0', '0', '0', '0']
# ['인장', '전과조회', '1', '1', '0', '0', '0']
# ['인장', '기타', '227', '204', '156', '127', '108']
# ['공무원범죄', '현행범', '20', '18', '3', '0', '5']
# ['공무원범죄', '피해자신고', '8', '8', '10', '17', '19']
# ['공무원범죄', '고소', '483', '492', '571', '577', '518']
# ['공무원범죄', '고발', '150', '162', '228', '247', '305']
# ['공무원범죄', '자수', '3', '1', '2', '2', '2']
# ['공무원범죄', '민간체포', '1', '0', '0', '1', '0']
# ['공무원범죄', '진정투서', '31', '41', '47', '37', '75']
# ['공무원범죄', '타인신고', '5', '4', '5', '11', '23']
# ['공무원범죄', '신문', '3', '9', '4', '17', '0']
# ['공무원범죄', '불심검문', '0', '1', '0', '1', '0']
# ['공무원범죄', '탐문정보', '237', '231', '248', '198', '102']
# ['공무원범죄', '안면식별', '0', '0', '0', '0', '0']
# ['공무원범죄', '감식자료', '0', '1', '0', '0', '0']
# ['공무원범죄', '변사체', '0', '0', '0', '0', '0']
# ['공무원범죄', '범죄수법', '13', '0', '0', '0', '0']
# ['공무원범죄', '발자국', '0', '0', '0', '0', '0']
# ['공무원범죄', '검사지휘', '10', '25', '12', '28', '14']
# ['공무원범죄', '타기관에서 이송', '6', '5', '11', '5', '8']
# ['공무원범죄', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['공무원범죄', '장물', '0', '0', '0', '0', '0']
# ['공무원범죄', '전과조회', '0', '0', '0', '0', '0']
# ['공무원범죄', '기타', '1287', '1562', '1505', '1284', '959']
# ['직무유기', '현행범', '1', '1', '1', '0', '0']
# ['직무유기', '피해자신고', '2', '2', '3', '3', '8']
# ['직무유기', '고소', '218', '201', '267', '246', '200']
# ['직무유기', '고발', '86', '89', '99', '102', '154']
# ['직무유기', '자수', '0', '0', '1', '0', '0']
# ['직무유기', '민간체포', '0', '0', '0', '0', '0']
# ['직무유기', '진정투서', '10', '11', '7', '9', '7']
# ['직무유기', '타인신고', '0', '1', '0', '1', '3']
# ['직무유기', '신문', '0', '0', '0', '4', '0']
# ['직무유기', '불심검문', '0', '0', '0', '0', '0']
# ['직무유기', '탐문정보', '42', '11', '29', '24', '9']
# ['직무유기', '안면식별', '0', '0', '0', '0', '0']
# ['직무유기', '감식자료', '0', '1', '0', '0', '0']
# ['직무유기', '변사체', '0', '0', '0', '0', '0']
# ['직무유기', '범죄수법', '0', '0', '0', '0', '0']
# ['직무유기', '발자국', '0', '0', '0', '0', '0']
# ['직무유기', '검사지휘', '5', '3', '3', '7', '6']
# ['직무유기', '타기관에서 이송', '0', '0', '0', '0', '0']
# ['직무유기', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['직무유기', '장물', '0', '0', '0', '0', '0']
# ['직무유기', '전과조회', '0', '0', '0', '0', '0']
# ['직무유기', '기타', '318', '389', '398', '332', '266']
# ['직권남용', '현행범', '1', '0', '0', '0', '1']
# ['직권남용', '피해자신고', '5', '5', '3', '10', '8']
# ['직권남용', '고소', '248', '264', '276', '304', '288']
# ['직권남용', '고발', '21', '36', '64', '92', '92']
# ['직권남용', '자수', '0', '0', '0', '0', '1']
# ['직권남용', '민간체포', '1', '0', '0', '0', '0']
# ['직권남용', '진정투서', '6', '8', '11', '6', '27']
# ['직권남용', '타인신고', '1', '0', '1', '1', '8']
# ['직권남용', '신문', '0', '0', '0', '11', '0']
# ['직권남용', '불심검문', '0', '0', '0', '0', '0']
# ['직권남용', '탐문정보', '16', '25', '82', '87', '19']
# ['직권남용', '안면식별', '0', '0', '0', '0', '0']
# ['직권남용', '감식자료', '0', '0', '0', '0', '0']
# ['직권남용', '변사체', '0', '0', '0', '0', '0']
# ['직권남용', '범죄수법', '0', '0', '0', '0', '0']
# ['직권남용', '발자국', '0', '0', '0', '0', '0']
# ['직권남용', '검사지휘', '0', '6', '8', '13', '5']
# ['직권남용', '타기관에서 이송', '2', '0', '2', '2', '1']
# ['직권남용', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['직권남용', '장물', '0', '0', '0', '0', '0']
# ['직권남용', '전과조회', '0', '0', '0', '0', '0']
# ['직권남용', '기타', '353', '457', '508', '529', '435']
# ['수뢰', '현행범', '6', '9', '0', '0', '1']
# ['수뢰', '피해자신고', '1', '0', '3', '3', '2']
# ['수뢰', '고소', '13', '22', '28', '23', '26']
# ['수뢰', '고발', '36', '25', '57', '45', '49']
# ['수뢰', '자수', '1', '1', '1', '2', '1']
# ['수뢰', '민간체포', '0', '0', '0', '1', '0']
# ['수뢰', '진정투서', '11', '18', '25', '21', '37']
# ['수뢰', '타인신고', '2', '3', '4', '9', '12']
# ['수뢰', '신문', '1', '6', '1', '1', '0']
# ['수뢰', '불심검문', '0', '0', '0', '0', '0']
# ['수뢰', '탐문정보', '129', '146', '114', '71', '62']
# ['수뢰', '안면식별', '0', '0', '0', '0', '0']
# ['수뢰', '감식자료', '0', '0', '0', '0', '0']
# ['수뢰', '변사체', '0', '0', '0', '0', '0']
# ['수뢰', '범죄수법', '7', '0', '0', '0', '0']
# ['수뢰', '발자국', '0', '0', '0', '0', '0']
# ['수뢰', '검사지휘', '3', '12', '1', '8', '3']
# ['수뢰', '타기관에서 이송', '3', '5', '4', '2', '5']
# ['수뢰', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['수뢰', '장물', '0', '0', '0', '0', '0']
# ['수뢰', '전과조회', '0', '0', '0', '0', '0']
# ['수뢰', '기타', '371', '437', '415', '287', '182']
# ['증뢰', '현행범', '12', '8', '2', '0', '3']
# ['증뢰', '피해자신고', '0', '1', '1', '1', '1']
# ['증뢰', '고소', '4', '5', '0', '4', '4']
# ['증뢰', '고발', '7', '12', '8', '8', '10']
# ['증뢰', '자수', '2', '0', '0', '0', '0']
# ['증뢰', '민간체포', '0', '0', '0', '0', '0']
# ['증뢰', '진정투서', '4', '4', '4', '1', '4']
# ['증뢰', '타인신고', '2', '0', '0', '0', '0']
# ['증뢰', '신문', '2', '3', '3', '1', '0']
# ['증뢰', '불심검문', '0', '1', '0', '1', '0']
# ['증뢰', '탐문정보', '50', '49', '23', '16', '12']
# ['증뢰', '안면식별', '0', '0', '0', '0', '0']
# ['증뢰', '감식자료', '0', '0', '0', '0', '0']
# ['증뢰', '변사체', '0', '0', '0', '0', '0']
# ['증뢰', '범죄수법', '6', '0', '0', '0', '0']
# ['증뢰', '발자국', '0', '0', '0', '0', '0']
# ['증뢰', '검사지휘', '2', '4', '0', '0', '0']
# ['증뢰', '타기관에서 이송', '1', '0', '5', '1', '2']
# ['증뢰', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['증뢰', '장물', '0', '0', '0', '0', '0']
# ['증뢰', '전과조회', '0', '0', '0', '0', '0']
# ['증뢰', '기타', '245', '279', '184', '136', '76']
# ['풍속범죄', '현행범', '2034', '1773', '1246', '1153', '852']
# ['풍속범죄', '피해자신고', '1111', '1325', '1149', '1412', '1366']
# ['풍속범죄', '고소', '201', '202', '257', '218', '157']
# ['풍속범죄', '고발', '37', '61', '96', '147', '121']
# ['풍속범죄', '자수', '58', '45', '27', '41', '45']
# ['풍속범죄', '민간체포', '6', '6', '1', '4', '3']
# ['풍속범죄', '진정투서', '237', '273', '118', '146', '194']
# ['풍속범죄', '타인신고', '2403', '2301', '2110', '2323', '2126']
# ['풍속범죄', '신문', '6', '5', '3', '2', '3']
# ['풍속범죄', '불심검문', '32', '28', '18', '19', '12']
# ['풍속범죄', '탐문정보', '5300', '2381', '1374', '2611', '2891']
# ['풍속범죄', '안면식별', '4', '1', '0', '0', '1']
# ['풍속범죄', '감식자료', '0', '2', '2', '0', '1']
# ['풍속범죄', '변사체', '5', '3', '1', '1', '1']
# ['풍속범죄', '범죄수법', '3', '6', '4', '1', '1']
# ['풍속범죄', '발자국', '0', '0', '0', '0', '0']
# ['풍속범죄', '검사지휘', '28', '24', '24', '26', '21']
# ['풍속범죄', '타기관에서 이송', '25', '18', '20', '34', '30']
# ['풍속범죄', '범행도구등 발견', '5', '1', '0', '2', '9']
# ['풍속범죄', '장물', '0', '0', '0', '0', '0']
# ['풍속범죄', '전과조회', '2', '0', '0', '0', '1']
# ['풍속범죄', '기타', '3506', '2953', '1864', '2426', '2257']
# ['도박과복표', '현행범', '1451', '1065', '810', '733', '562']
# ['도박과복표', '피해자신고', '185', '142', '118', '203', '172']
# ['도박과복표', '고소', '26', '22', '21', '17', '32']
# ['도박과복표', '고발', '24', '41', '67', '71', '107']
# ['도박과복표', '자수', '55', '43', '22', '38', '44']
# ['도박과복표', '민간체포', '2', '0', '0', '0', '0']
# ['도박과복표', '진정투서', '226', '263', '108', '130', '179']
# ['도박과복표', '타인신고', '2079', '1836', '1670', '1778', '1663']
# ['도박과복표', '신문', '6', '3', '3', '1', '1']
# ['도박과복표', '불심검문', '22', '16', '12', '13', '7']
# ['도박과복표', '탐문정보', '5222', '2307', '1317', '2547', '2844']
# ['도박과복표', '안면식별', '0', '0', '0', '0', '0']
# ['도박과복표', '감식자료', '0', '0', '0', '0', '0']
# ['도박과복표', '변사체', '2', '0', '0', '0', '0']
# ['도박과복표', '범죄수법', '2', '1', '0', '0', '0']
# ['도박과복표', '발자국', '0', '0', '0', '0', '0']
# ['도박과복표', '검사지휘', '28', '23', '21', '23', '16']
# ['도박과복표', '타기관에서 이송', '24', '16', '19', '34', '30']
# ['도박과복표', '범행도구등 발견', '5', '1', '0', '2', '9']
# ['도박과복표', '장물', '0', '0', '0', '0', '0']
# ['도박과복표', '전과조회', '2', '0', '0', '0', '0']
# ['도박과복표', '기타', '3433', '2863', '1755', '2316', '2154']
# ['신앙', '현행범', '15', '14', '12', '7', '3']
# ['신앙', '피해자신고', '27', '26', '22', '19', '23']
# ['신앙', '고소', '159', '167', '216', '183', '97']
# ['신앙', '고발', '3', '12', '23', '75', '12']
# ['신앙', '자수', '2', '1', '1', '1', '1']
# ['신앙', '민간체포', '0', '0', '0', '0', '0']
# ['신앙', '진정투서', '4', '8', '5', '5', '8']
# ['신앙', '타인신고', '3', '8', '13', '10', '4']
# ['신앙', '신문', '0', '1', '0', '0', '0']
# ['신앙', '불심검문', '0', '0', '0', '0', '0']
# ['신앙', '탐문정보', '6', '1', '7', '1', '2']
# ['신앙', '안면식별', '0', '0', '0', '0', '0']
# ['신앙', '감식자료', '0', '0', '0', '0', '0']
# ['신앙', '변사체', '3', '3', '1', '0', '1']
# ['신앙', '범죄수법', '0', '0', '0', '0', '0']
# ['신앙', '발자국', '0', '0', '0', '0', '0']
# ['신앙', '검사지휘', '0', '0', '2', '2', '4']
# ['신앙', '타기관에서 이송', '0', '1', '0', '0', '0']
# ['신앙', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['신앙', '장물', '0', '0', '0', '0', '0']
# ['신앙', '전과조회', '0', '0', '0', '0', '0']
# ['신앙', '기타', '9', '17', '20', '19', '8']
# ['기타음란행위', '현행범', '568', '694', '424', '413', '287']
# ['기타음란행위', '피해자신고', '899', '1157', '1009', '1190', '1171']
# ['기타음란행위', '고소', '16', '13', '20', '18', '28']
# ['기타음란행위', '고발', '10', '8', '6', '1', '2']
# ['기타음란행위', '자수', '1', '1', '4', '2', '0']
# ['기타음란행위', '민간체포', '4', '6', '1', '4', '3']
# ['기타음란행위', '진정투서', '7', '2', '5', '11', '7']
# ['기타음란행위', '타인신고', '321', '457', '427', '535', '459']
# ['기타음란행위', '신문', '0', '1', '0', '1', '2']
# ['기타음란행위', '불심검문', '10', '12', '6', '6', '5']
# ['기타음란행위', '탐문정보', '72', '73', '50', '63', '45']
# ['기타음란행위', '안면식별', '4', '1', '0', '0', '1']
# ['기타음란행위', '감식자료', '0', '2', '2', '0', '1']
# ['기타음란행위', '변사체', '0', '0', '0', '1', '0']
# ['기타음란행위', '범죄수법', '1', '5', '4', '1', '1']
# ['기타음란행위', '발자국', '0', '0', '0', '0', '0']
# ['기타음란행위', '검사지휘', '0', '1', '1', '1', '1']
# ['기타음란행위', '타기관에서 이송', '1', '1', '1', '0', '0']
# ['기타음란행위', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['기타음란행위', '장물', '0', '0', '0', '0', '0']
# ['기타음란행위', '전과조회', '0', '0', '0', '0', '1']
# ['기타음란행위', '기타', '64', '73', '89', '91', '95']
# ['과실범죄', '현행범', '162', '148', '119', '96', '68']
# ['과실범죄', '피해자신고', '2060', '2346', '2473', '2580', '2394']
# ['과실범죄', '고소', '1884', '1995', '2266', '2273', '2303']
# ['과실범죄', '고발', '16', '28', '30', '41', '40']
# ['과실범죄', '자수', '46', '44', '31', '46', '36']
# ['과실범죄', '민간체포', '0', '0', '0', '0', '0']
# ['과실범죄', '진정투서', '230', '241', '237', '252', '236']
# ['과실범죄', '타인신고', '1284', '1437', '1444', '1555', '1534']
# ['과실범죄', '신문', '18', '10', '3', '6', '2']
# ['과실범죄', '불심검문', '3', '7', '3', '1', '1']
# ['과실범죄', '탐문정보', '129', '143', '143', '182', '178']
# ['과실범죄', '안면식별', '0', '1', '1', '0', '0']
# ['과실범죄', '감식자료', '28', '25', '19', '21', '20']
# ['과실범죄', '변사체', '360', '378', '388', '308', '265']
# ['과실범죄', '범죄수법', '0', '0', '1', '0', '0']
# ['과실범죄', '발자국', '0', '0', '0', '0', '0']
# ['과실범죄', '검사지휘', '17', '21', '19', '25', '35']
# ['과실범죄', '타기관에서 이송', '4', '6', '15', '12', '9']
# ['과실범죄', '범행도구등 발견', '1', '3', '2', '2', '2']
# ['과실범죄', '장물', '0', '0', '0', '0', '0']
# ['과실범죄', '전과조회', '0', '0', '1', '0', '0']
# ['과실범죄', '기타', '670', '717', '735', '802', '716']
# ['과실치사상', '현행범', '114', '107', '86', '64', '42']
# ['과실치사상', '피해자신고', '881', '1051', '1110', '1276', '1141']
# ['과실치사상', '고소', '690', '790', '910', '967', '886']
# ['과실치사상', '고발', '3', '4', '2', '3', '7']
# ['과실치사상', '자수', '0', '5', '3', '4', '4']
# ['과실치사상', '민간체포', '0', '0', '0', '0', '0']
# ['과실치사상', '진정투서', '136', '127', '124', '136', '137']
# ['과실치사상', '타인신고', '59', '84', '100', '108', '120']
# ['과실치사상', '신문', '1', '0', '0', '1', '0']
# ['과실치사상', '불심검문', '0', '1', '1', '0', '0']
# ['과실치사상', '탐문정보', '19', '23', '26', '40', '42']
# ['과실치사상', '안면식별', '0', '0', '0', '0', '0']
# ['과실치사상', '감식자료', '0', '0', '1', '1', '0']
# ['과실치사상', '변사체', '9', '11', '14', '11', '9']
# ['과실치사상', '범죄수법', '0', '0', '1', '0', '0']
# ['과실치사상', '발자국', '0', '0', '0', '0', '0']
# ['과실치사상', '검사지휘', '2', '5', '7', '5', '12']
# ['과실치사상', '타기관에서 이송', '0', '1', '4', '1', '2']
# ['과실치사상', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['과실치사상', '장물', '0', '0', '0', '0', '0']
# ['과실치사상', '전과조회', '0', '0', '0', '0', '0']
# ['과실치사상', '기타', '74', '79', '82', '89', '106']
# ['업무상과실치사상', '현행범', '5', '5', '4', '5', '4']
# ['업무상과실치사상', '피해자신고', '522', '524', '524', '570', '529']
# ['업무상과실치사상', '고소', '1176', '1179', '1329', '1295', '1400']
# ['업무상과실치사상', '고발', '13', '24', '27', '33', '31']
# ['업무상과실치사상', '자수', '22', '15', '14', '12', '14']
# ['업무상과실치사상', '민간체포', '0', '0', '0', '0', '0']
# ['업무상과실치사상', '진정투서', '93', '110', '109', '111', '98']
# ['업무상과실치사상', '타인신고', '592', '646', '607', '704', '661']
# ['업무상과실치사상', '신문', '8', '7', '2', '3', '1']
# ['업무상과실치사상', '불심검문', '1', '2', '1', '0', '1']
# ['업무상과실치사상', '탐문정보', '48', '37', '40', '61', '35']
# ['업무상과실치사상', '안면식별', '0', '0', '0', '0', '0']
# ['업무상과실치사상', '감식자료', '0', '0', '2', '0', '0']
# ['업무상과실치사상', '변사체', '351', '366', '374', '295', '256']
# ['업무상과실치사상', '범죄수법', '0', '0', '0', '0', '0']
# ['업무상과실치사상', '발자국', '0', '0', '0', '0', '0']
# ['업무상과실치사상', '검사지휘', '15', '16', '11', '20', '23']
# ['업무상과실치사상', '타기관에서 이송', '3', '4', '6', '8', '4']
# ['업무상과실치사상', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['업무상과실치사상', '장물', '0', '0', '0', '0', '0']
# ['업무상과실치사상', '전과조회', '0', '0', '0', '0', '0']
# ['업무상과실치사상', '기타', '406', '435', '430', '486', '403']
# ['실화', '현행범', '43', '36', '29', '27', '22']
# ['실화', '피해자신고', '657', '771', '839', '734', '724']
# ['실화', '고소', '18', '26', '27', '11', '17']
# ['실화', '고발', '0', '0', '1', '5', '2']
# ['실화', '자수', '24', '24', '14', '30', '18']
# ['실화', '민간체포', '0', '0', '0', '0', '0']
# ['실화', '진정투서', '1', '4', '4', '5', '1']
# ['실화', '타인신고', '633', '707', '737', '743', '753']
# ['실화', '신문', '9', '3', '1', '2', '1']
# ['실화', '불심검문', '2', '4', '1', '1', '0']
# ['실화', '탐문정보', '62', '83', '77', '81', '101']
# ['실화', '안면식별', '0', '1', '1', '0', '0']
# ['실화', '감식자료', '28', '25', '16', '20', '20']
# ['실화', '변사체', '0', '1', '0', '2', '0']
# ['실화', '범죄수법', '0', '0', '0', '0', '0']
# ['실화', '발자국', '0', '0', '0', '0', '0']
# ['실화', '검사지휘', '0', '0', '1', '0', '0']
# ['실화', '타기관에서 이송', '1', '1', '5', '3', '3']
# ['실화', '범행도구등 발견', '1', '3', '2', '2', '2']
# ['실화', '장물', '0', '0', '0', '0', '0']
# ['실화', '전과조회', '0', '0', '1', '0', '0']
# ['실화', '기타', '190', '203', '223', '227', '207']
# ['기타형법범죄', '현행범', '27710', '24130', '21584', '19808', '17136']
# ['기타형법범죄', '피해자신고', '13378', '13377', '15165', '18434', '19898']
# ['기타형법범죄', '고소', '36395', '36741', '40298', '40526', '38324']
# ['기타형법범죄', '고발', '560', '554', '666', '833', '872']
# ['기타형법범죄', '자수', '49', '54', '49', '60', '62']
# ['기타형법범죄', '민간체포', '12', '5', '8', '9', '7']
# ['기타형법범죄', '진정투서', '838', '784', '721', '624', '733']
# ['기타형법범죄', '타인신고', '1057', '987', '1311', '1295', '1372']
# ['기타형법범죄', '신문', '48', '68', '73', '63', '30']
# ['기타형법범죄', '불심검문', '101', '69', '43', '29', '24']
# ['기타형법범죄', '탐문정보', '1754', '1218', '1536', '1481', '984']
# ['기타형법범죄', '안면식별', '20', '1', '5', '5', '4']
# ['기타형법범죄', '감식자료', '16', '8', '12', '12', '7']
# ['기타형법범죄', '변사체', '4', '7', '10', '7', '10']
# ['기타형법범죄', '범죄수법', '6', '5', '6', '1', '6']
# ['기타형법범죄', '발자국', '2', '0', '1', '1', '0']
# ['기타형법범죄', '검사지휘', '200', '204', '300', '366', '456']
# ['기타형법범죄', '타기관에서 이송', '21', '14', '30', '26', '30']
# ['기타형법범죄', '범행도구등 발견', '3', '5', '4', '3', '0']
# ['기타형법범죄', '장물', '1', '2', '0', '0', '0']
# ['기타형법범죄', '전과조회', '1', '2', '5', '2', '1']
# ['기타형법범죄', '기타', '7416', '6844', '6150', '5762', '5359']
# ['명예', '현행범', '2533', '1982', '1452', '1223', '736']
# ['명예', '피해자신고', '1245', '1239', '1385', '1573', '1504']
# ['명예', '고소', '18153', '16496', '18168', '19273', '19298']
# ['명예', '고발', '56', '59', '112', '97', '80']
# ['명예', '자수', '1', '3', '0', '2', '11']
# ['명예', '민간체포', '0', '0', '0', '1', '0']
# ['명예', '진정투서', '347', '347', '314', '269', '235']
# ['명예', '타인신고', '138', '127', '148', '169', '112']
# ['명예', '신문', '0', '1', '5', '12', '4']
# ['명예', '불심검문', '15', '11', '3', '2', '0']
# ['명예', '탐문정보', '84', '71', '80', '76', '78']
# ['명예', '안면식별', '0', '0', '0', '0', '0']
# ['명예', '감식자료', '0', '2', '0', '0', '0']
# ['명예', '변사체', '0', '0', '0', '0', '0']
# ['명예', '범죄수법', '0', '0', '0', '0', '0']
# ['명예', '발자국', '0', '0', '0', '0', '0']
# ['명예', '검사지휘', '55', '58', '98', '148', '168']
# ['명예', '타기관에서 이송', '7', '3', '3', '4', '7']
# ['명예', '범행도구등 발견', '2', '0', '0', '0', '0']
# ['명예', '장물', '0', '0', '0', '0', '0']
# ['명예', '전과조회', '0', '0', '0', '0', '0']
# ['명예', '기타', '857', '832', '948', '899', '979']
# ['권리행사방해', '현행범', '19', '15', '9', '9', '8']
# ['권리행사방해', '피해자신고', '193', '202', '192', '230', '248']
# ['권리행사방해', '고소', '6940', '9201', '10181', '9002', '6408']
# ['권리행사방해', '고발', '46', '57', '50', '68', '56']
# ['권리행사방해', '자수', '4', '2', '2', '6', '3']
# ['권리행사방해', '민간체포', '0', '0', '0', '0', '0']
# ['권리행사방해', '진정투서', '40', '38', '35', '27', '28']
# ['권리행사방해', '타인신고', '15', '15', '13', '25', '17']
# ['권리행사방해', '신문', '0', '1', '6', '2', '1']
# ['권리행사방해', '불심검문', '9', '11', '14', '7', '2']
# ['권리행사방해', '탐문정보', '91', '53', '47', '43', '30']
# ['권리행사방해', '안면식별', '0', '0', '0', '0', '0']
# ['권리행사방해', '감식자료', '1', '0', '0', '0', '0']
# ['권리행사방해', '변사체', '0', '0', '3', '0', '2']
# ['권리행사방해', '범죄수법', '0', '0', '0', '0', '0']
# ['권리행사방해', '발자국', '0', '0', '0', '0', '0']
# ['권리행사방해', '검사지휘', '27', '25', '45', '49', '60']
# ['권리행사방해', '타기관에서 이송', '1', '1', '5', '5', '3']
# ['권리행사방해', '범행도구등 발견', '0', '0', '1', '0', '0']
# ['권리행사방해', '장물', '0', '0', '0', '0', '0']
# ['권리행사방해', '전과조회', '0', '0', '1', '1', '0']
# ['권리행사방해', '기타', '284', '395', '393', '422', '306']
# ['신용업무경매', '현행범', '10906', '9908', '9033', '7816', '6348']
# ['신용업무경매', '피해자신고', '6210', '6190', '7065', '8084', '8656']
# ['신용업무경매', '고소', '4011', '3857', '4126', '4340', '4506']
# ['신용업무경매', '고발', '154', '165', '183', '270', '313']
# ['신용업무경매', '자수', '8', '6', '5', '6', '10']
# ['신용업무경매', '민간체포', '0', '0', '2', '1', '0']
# ['신용업무경매', '진정투서', '198', '178', '179', '157', '205']
# ['신용업무경매', '타인신고', '145', '162', '228', '243', '273']
# ['신용업무경매', '신문', '2', '7', '3', '2', '3']
# ['신용업무경매', '불심검문', '6', '5', '1', '1', '4']
# ['신용업무경매', '탐문정보', '892', '664', '1039', '245', '362']
# ['신용업무경매', '안면식별', '0', '0', '1', '0', '2']
# ['신용업무경매', '감식자료', '0', '1', '0', '0', '0']
# ['신용업무경매', '변사체', '0', '0', '0', '0', '0']
# ['신용업무경매', '범죄수법', '0', '0', '0', '0', '0']
# ['신용업무경매', '발자국', '0', '0', '0', '1', '0']
# ['신용업무경매', '검사지휘', '26', '35', '45', '54', '62']
# ['신용업무경매', '타기관에서 이송', '6', '2', '11', '7', '9']
# ['신용업무경매', '범행도구등 발견', '1', '1', '0', '0', '0']
# ['신용업무경매', '장물', '1', '0', '0', '0', '0']
# ['신용업무경매', '전과조회', '0', '0', '2', '1', '0']
# ['신용업무경매', '기타', '1421', '798', '839', '898', '927']
# ['주거침입', '현행범', '2955', '2660', '2724', '2942', '2625']
# ['주거침입', '피해자신고', '3741', '4093', '4964', '6610', '7492']
# ['주거침입', '고소', '1498', '1533', '1716', '1898', '1998']
# ['주거침입', '고발', '32', '19', '33', '32', '51']
# ['주거침입', '자수', '11', '9', '12', '20', '17']
# ['주거침입', '민간체포', '11', '5', '4', '7', '5']
# ['주거침입', '진정투서', '82', '107', '106', '85', '153']
# ['주거침입', '타인신고', '123', '129', '182', '222', '250']
# ['주거침입', '신문', '3', '3', '4', '2', '3']
# ['주거침입', '불심검문', '10', '4', '1', '3', '4']
# ['주거침입', '탐문정보', '125', '127', '169', '209', '275']
# ['주거침입', '안면식별', '7', '1', '2', '4', '2']
# ['주거침입', '감식자료', '9', '5', '12', '11', '7']
# ['주거침입', '변사체', '0', '0', '1', '0', '1']
# ['주거침입', '범죄수법', '1', '3', '5', '1', '3']
# ['주거침입', '발자국', '2', '0', '1', '0', '0']
# ['주거침입', '검사지휘', '12', '16', '23', '21', '36']
# ['주거침입', '타기관에서 이송', '1', '2', '1', '1', '2']
# ['주거침입', '범행도구등 발견', '0', '3', '1', '2', '0']
# ['주거침입', '장물', '0', '2', '0', '0', '0']
# ['주거침입', '전과조회', '0', '0', '1', '0', '1']
# ['주거침입', '기타', '270', '271', '298', '330', '380']
# ['비밀침해', '현행범', '0', '0', '1', '0', '0']
# ['비밀침해', '피해자신고', '1', '1', '1', '6', '5']
# ['비밀침해', '고소', '55', '54', '60', '79', '83']
# ['비밀침해', '고발', '3', '3', '1', '2', '0']
# ['비밀침해', '자수', '0', '0', '0', '0', '0']
# ['비밀침해', '민간체포', '0', '0', '0', '0', '0']
# ['비밀침해', '진정투서', '2', '1', '1', '0', '1']
# ['비밀침해', '타인신고', '0', '0', '0', '0', '0']
# ['비밀침해', '신문', '0', '0', '0', '0', '0']
# ['비밀침해', '불심검문', '0', '0', '0', '0', '0']
# ['비밀침해', '탐문정보', '0', '0', '0', '0', '0']
# ['비밀침해', '안면식별', '0', '0', '0', '0', '0']
# ...
# ['축산물위생관리법', '자수', '0', '0', '0', '1', '0']
# ['축산물위생관리법', '민간체포', '0', '0', '0', '0', '0']
# ['축산물위생관리법', '진정투서', '12', '4', '5', '8', '2']
# ['축산물위생관리법', '타인신고', '32', '20', '11', '15', '15']
# ['축산물위생관리법', '신문', '6', '6', '2', '3', '0']
# ['축산물위생관리법', '불심검문', '5', '27', '2', '2', '0']
# ['축산물위생관리법', '탐문정보', '511', '419', '29', '11', '5']
# ['축산물위생관리법', '안면식별', '0', '0', '0', '0', '0']
# ['축산물위생관리법', '감식자료', '0', '0', '0', '0', '0']
# ['축산물위생관리법', '변사체', '0', '0', '0', '0', '0']
# ['축산물위생관리법', '범죄수법', '0', '0', '0', '0', '0']
# ['축산물위생관리법', '발자국', '0', '0', '0', '0', '0']
# ['축산물위생관리법', '검사지휘', '0', '1', '1', '1', '0']
# ['축산물위생관리법', '타기관에서 이송', '4', '0', '1', '1', '0']
# ['축산물위생관리법', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['축산물위생관리법', '장물', '0', '0', '0', '0', '0']
# ['축산물위생관리법', '전과조회', '0', '0', '0', '0', '0']
# ['축산물위생관리법', '기타', '483', '970', '200', '236', '156']
# ['출입국관리법', '현행범', '226', '203', '261', '357', '300']
# ['출입국관리법', '피해자신고', '22', '34', '29', '61', '68']
# ['출입국관리법', '고소', '13', '18', '18', '26', '12']
# ['출입국관리법', '고발', '1762', '1278', '1366', '1567', '938']
# ['출입국관리법', '자수', '2', '2', '4', '3', '2']
# ['출입국관리법', '민간체포', '0', '1', '0', '1', '0']
# ['출입국관리법', '진정투서', '2', '2', '6', '3', '6']
# ['출입국관리법', '타인신고', '54', '68', '114', '236', '193']
# ['출입국관리법', '신문', '2', '1', '2', '0', '0']
# ['출입국관리법', '불심검문', '71', '47', '30', '59', '49']
# ['출입국관리법', '탐문정보', '83', '52', '106', '278', '172']
# ['출입국관리법', '안면식별', '0', '0', '0', '0', '0']
# ['출입국관리법', '감식자료', '1', '0', '0', '0', '0']
# ['출입국관리법', '변사체', '0', '0', '1', '2', '2']
# ['출입국관리법', '범죄수법', '0', '1', '0', '1', '0']
# ['출입국관리법', '발자국', '0', '0', '0', '0', '0']
# ['출입국관리법', '검사지휘', '55', '47', '67', '94', '36']
# ['출입국관리법', '타기관에서 이송', '2', '2', '2', '4', '4']
# ['출입국관리법', '범행도구등 발견', '0', '0', '0', '0', '1']
# ['출입국관리법', '장물', '0', '0', '0', '0', '0']
# ['출입국관리법', '전과조회', '0', '1', '0', '0', '0']
# ['출입국관리법', '기타', '551', '484', '439', '1354', '643']
# ['통신비밀보호법', '현행범', '1', '5', '6', '3', '0']
# ['통신비밀보호법', '피해자신고', '12', '6', '8', '19', '15']
# ['통신비밀보호법', '고소', '96', '85', '128', '164', '161']
# ['통신비밀보호법', '고발', '7', '8', '9', '4', '10']
# ['통신비밀보호법', '자수', '0', '0', '0', '2', '0']
# ['통신비밀보호법', '민간체포', '0', '0', '0', '0', '0']
# ['통신비밀보호법', '진정투서', '2', '5', '3', '6', '13']
# ['통신비밀보호법', '타인신고', '5', '3', '1', '4', '3']
# ['통신비밀보호법', '신문', '0', '0', '0', '0', '0']
# ['통신비밀보호법', '불심검문', '0', '0', '0', '0', '0']
# ['통신비밀보호법', '탐문정보', '9', '28', '20', '4', '8']
# ['통신비밀보호법', '안면식별', '0', '0', '0', '0', '0']
# ['통신비밀보호법', '감식자료', '0', '0', '0', '0', '0']
# ['통신비밀보호법', '변사체', '0', '0', '0', '0', '1']
# ['통신비밀보호법', '범죄수법', '0', '0', '0', '0', '0']
# ['통신비밀보호법', '발자국', '0', '0', '0', '1', '0']
# ['통신비밀보호법', '검사지휘', '1', '0', '3', '3', '2']
# ['통신비밀보호법', '타기관에서 이송', '0', '0', '0', '0', '0']
# ['통신비밀보호법', '범행도구등 발견', '0', '0', '0', '1', '0']
# ['통신비밀보호법', '장물', '0', '0', '0', '0', '0']
# ['통신비밀보호법', '전과조회', '0', '0', '0', '0', '0']
# ['통신비밀보호법', '기타', '15', '23', '30', '32', '41']
# ['특가법(도주차량)', '현행범', '84', '43', '24', '7', '72']
# ['특가법(도주차량)', '피해자신고', '6324', '3485', '1977', '227', '7015']
# ['특가법(도주차량)', '고소', '5', '5', '4', '2', '21']
# ['특가법(도주차량)', '고발', '0', '0', '0', '3', '1']
# ['특가법(도주차량)', '자수', '278', '121', '71', '8', '193']
# ['특가법(도주차량)', '민간체포', '7', '8', '2', '0', '2']
# ['특가법(도주차량)', '진정투서', '2', '0', '0', '0', '0']
# ['특가법(도주차량)', '타인신고', '549', '249', '190', '25', '633']
# ['특가법(도주차량)', '신문', '0', '2', '1', '0', '3']
# ['특가법(도주차량)', '불심검문', '62', '32', '22', '4', '55']
# ['특가법(도주차량)', '탐문정보', '259', '121', '63', '9', '216']
# ['특가법(도주차량)', '안면식별', '0', '0', '0', '0', '0']
# ['특가법(도주차량)', '감식자료', '1', '0', '0', '0', '3']
# ['특가법(도주차량)', '변사체', '3', '1', '1', '0', '0']
# ['특가법(도주차량)', '범죄수법', '1', '0', '0', '0', '0']
# ['특가법(도주차량)', '발자국', '0', '0', '0', '0', '0']
# ['특가법(도주차량)', '검사지휘', '1', '0', '1', '0', '1']
# ['특가법(도주차량)', '타기관에서 이송', '2', '1', '1', '1', '2']
# ['특가법(도주차량)', '범행도구등 발견', '1', '1', '0', '1', '3']
# ['특가법(도주차량)', '장물', '0', '0', '0', '0', '0']
# ['특가법(도주차량)', '전과조회', '0', '0', '0', '0', '1']
# ['특가법(도주차량)', '기타', '984', '470', '317', '73', '1067']
# ['특허법', '현행범', '0', '0', '0', '0', '0']
# ['특허법', '피해자신고', '0', '0', '0', '1', '0']
# ['특허법', '고소', '141', '161', '125', '137', '118']
# ['특허법', '고발', '5', '0', '2', '5', '4']
# ['특허법', '자수', '0', '0', '0', '0', '0']
# ['특허법', '민간체포', '0', '0', '0', '0', '0']
# ['특허법', '진정투서', '0', '0', '2', '0', '0']
# ['특허법', '타인신고', '0', '0', '0', '0', '0']
# ['특허법', '신문', '0', '0', '0', '0', '0']
# ['특허법', '불심검문', '0', '0', '0', '0', '0']
# ['특허법', '탐문정보', '1', '0', '0', '0', '0']
# ['특허법', '안면식별', '0', '0', '0', '0', '0']
# ['특허법', '감식자료', '0', '0', '0', '0', '0']
# ['특허법', '변사체', '0', '0', '0', '0', '0']
# ['특허법', '범죄수법', '0', '0', '0', '0', '0']
# ['특허법', '발자국', '0', '0', '0', '0', '0']
# ['특허법', '검사지휘', '1', '3', '4', '3', '1']
# ['특허법', '타기관에서 이송', '0', '0', '0', '0', '0']
# ['특허법', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['특허법', '장물', '0', '0', '0', '0', '0']
# ['특허법', '전과조회', '0', '0', '0', '0', '0']
# ['특허법', '기타', '52', '7', '15', '33', '61']
# ['폐기물관리법', '현행범', '17', '51', '25', '28', '61']
# ['폐기물관리법', '피해자신고', '12', '15', '13', '7', '20']
# ['폐기물관리법', '고소', '37', '52', '64', '82', '78']
# ['폐기물관리법', '고발', '647', '798', '852', '993', '1026']
# ['폐기물관리법', '자수', '1', '2', '1', '0', '0']
# ['폐기물관리법', '민간체포', '0', '0', '0', '0', '0']
# ['폐기물관리법', '진정투서', '15', '27', '27', '57', '40']
# ['폐기물관리법', '타인신고', '50', '52', '38', '50', '72']
# ['폐기물관리법', '신문', '1', '1', '0', '2', '2']
# ['폐기물관리법', '불심검문', '3', '18', '3', '2', '1']
# ['폐기물관리법', '탐문정보', '87', '64', '102', '57', '36']
# ['폐기물관리법', '안면식별', '0', '0', '0', '0', '0']
# ['폐기물관리법', '감식자료', '0', '0', '0', '0', '0']
# ['폐기물관리법', '변사체', '0', '0', '0', '0', '0']
# ['폐기물관리법', '범죄수법', '0', '0', '0', '0', '0']
# ['폐기물관리법', '발자국', '0', '0', '0', '0', '0']
# ['폐기물관리법', '검사지휘', '0', '4', '5', '4', '3']
# ['폐기물관리법', '타기관에서 이송', '3', '6', '0', '3', '3']
# ['폐기물관리법', '범행도구등 발견', '1', '1', '0', '0', '0']
# ['폐기물관리법', '장물', '0', '0', '0', '0', '0']
# ['폐기물관리법', '전과조회', '0', '0', '0', '0', '0']
# ['폐기물관리법', '기타', '340', '448', '525', '528', '589']
# ['풍속영업의규제에관한법률', '현행범', '4', '8', '1', '1', '2']
# ['풍속영업의규제에관한법률', '피해자신고', '4', '1', '2', '2', '1']
# ['풍속영업의규제에관한법률', '고소', '2', '0', '3', '1', '0']
# ['풍속영업의규제에관한법률', '고발', '0', '1', '1', '1', '0']
# ['풍속영업의규제에관한법률', '자수', '1', '0', '0', '0', '0']
# ['풍속영업의규제에관한법률', '민간체포', '0', '0', '0', '0', '0']
# ['풍속영업의규제에관한법률', '진정투서', '2', '6', '2', '1', '0']
# ['풍속영업의규제에관한법률', '타인신고', '39', '36', '44', '24', '26']
# ['풍속영업의규제에관한법률', '신문', '0', '2', '0', '0', '0']
# ['풍속영업의규제에관한법률', '불심검문', '17', '29', '16', '7', '8']
# ['풍속영업의규제에관한법률', '탐문정보', '53', '38', '22', '12', '16']
# ['풍속영업의규제에관한법률', '안면식별', '0', '0', '0', '0', '0']
# ['풍속영업의규제에관한법률', '감식자료', '0', '0', '0', '0', '0']
# ['풍속영업의규제에관한법률', '변사체', '0', '0', '0', '0', '0']
# ['풍속영업의규제에관한법률', '범죄수법', '0', '0', '0', '0', '0']
# ['풍속영업의규제에관한법률', '발자국', '0', '0', '0', '0', '0']
# ['풍속영업의규제에관한법률', '검사지휘', '1', '0', '0', '0', '0']
# ['풍속영업의규제에관한법률', '타기관에서 이송', '0', '0', '0', '1', '0']
# ['풍속영업의규제에관한법률', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['풍속영업의규제에관한법률', '장물', '0', '0', '0', '0', '0']
# ['풍속영업의규제에관한법률', '전과조회', '0', '0', '0', '0', '0']
# ['풍속영업의규제에관한법률', '기타', '113', '83', '63', '37', '24']
# ['하천법', '현행범', '4', '0', '0', '19', '24']
# ['하천법', '피해자신고', '0', '0', '0', '0', '1']
# ['하천법', '고소', '3', '1', '2', '3', '2']
# ['하천법', '고발', '180', '173', '187', '177', '160']
# ['하천법', '자수', '1', '0', '0', '0', '0']
# ['하천법', '민간체포', '0', '0', '0', '0', '0']
# ['하천법', '진정투서', '2', '4', '0', '2', '2']
# ['하천법', '타인신고', '9', '16', '8', '10', '15']
# ['하천법', '신문', '1', '0', '0', '0', '0']
# ['하천법', '불심검문', '0', '0', '0', '2', '0']
# ['하천법', '탐문정보', '12', '5', '7', '7', '13']
# ['하천법', '안면식별', '0', '0', '0', '0', '0']
# ['하천법', '감식자료', '0', '0', '0', '0', '0']
# ['하천법', '변사체', '0', '0', '0', '0', '0']
# ['하천법', '범죄수법', '0', '0', '0', '0', '0']
# ['하천법', '발자국', '0', '0', '0', '0', '0']
# ['하천법', '검사지휘', '0', '0', '0', '1', '2']
# ['하천법', '타기관에서 이송', '0', '0', '0', '0', '0']
# ['하천법', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['하천법', '장물', '0', '0', '0', '0', '0']
# ['하천법', '전과조회', '0', '0', '0', '0', '0']
# ['하천법', '기타', '48', '11', '10', '35', '19']
# ['학교보건법', '현행범', '9', '1', '0', '0', '0']
# ['학교보건법', '피해자신고', '2', '1', '0', '0', '0']
# ['학교보건법', '고소', '4', '2', '0', '0', '0']
# ['학교보건법', '고발', '55', '21', '0', '0', '0']
# ['학교보건법', '자수', '1', '0', '0', '0', '0']
# ['학교보건법', '민간체포', '0', '0', '0', '0', '0']
# ['학교보건법', '진정투서', '3', '0', '0', '1', '0']
# ['학교보건법', '타인신고', '29', '5', '0', '0', '0']
# ['학교보건법', '신문', '0', '0', '0', '0', '0']
# ['학교보건법', '불심검문', '24', '2', '0', '0', '0']
# ['학교보건법', '탐문정보', '103', '7', '0', '3', '0']
# ['학교보건법', '안면식별', '0', '0', '0', '0', '0']
# ['학교보건법', '감식자료', '0', '0', '0', '0', '0']
# ['학교보건법', '변사체', '0', '0', '0', '0', '0']
# ['학교보건법', '범죄수법', '0', '0', '0', '0', '0']
# ['학교보건법', '발자국', '0', '0', '0', '0', '0']
# ['학교보건법', '검사지휘', '0', '0', '0', '0', '0']
# ['학교보건법', '타기관에서 이송', '0', '0', '0', '0', '0']
# ['학교보건법', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['학교보건법', '장물', '0', '0', '0', '0', '0']
# ['학교보건법', '전과조회', '0', '0', '0', '0', '0']
# ['학교보건법', '기타', '322', '41', '1', '5', '0']
# ['학원의설립운영및과외교습에관한법률', '현행범', '0', '0', '0', '0', '1']
# ['학원의설립운영및과외교습에관한법률', '피해자신고', '1', '0', '1', '0', '2']
# ['학원의설립운영및과외교습에관한법률', '고소', '6', '6', '15', '2', '9']
# ['학원의설립운영및과외교습에관한법률', '고발', '505', '484', '469', '382', '339']
# ['학원의설립운영및과외교습에관한법률', '자수', '0', '0', '0', '0', '0']
# ['학원의설립운영및과외교습에관한법률', '민간체포', '0', '0', '0', '0', '0']
# ['학원의설립운영및과외교습에관한법률', '진정투서', '6', '8', '4', '5', '6']
# ['학원의설립운영및과외교습에관한법률', '타인신고', '4', '4', '6', '4', '5']
# ['학원의설립운영및과외교습에관한법률', '신문', '0', '0', '0', '0', '0']
# ['학원의설립운영및과외교습에관한법률', '불심검문', '0', '0', '0', '0', '0']
# ['학원의설립운영및과외교습에관한법률', '탐문정보', '3', '0', '4', '0', '5']
# ['학원의설립운영및과외교습에관한법률', '안면식별', '0', '0', '0', '0', '0']
# ['학원의설립운영및과외교습에관한법률', '감식자료', '0', '0', '0', '0', '0']
# ['학원의설립운영및과외교습에관한법률', '변사체', '0', '0', '0', '0', '0']
# ['학원의설립운영및과외교습에관한법률', '범죄수법', '0', '0', '0', '0', '0']
# ['학원의설립운영및과외교습에관한법률', '발자국', '0', '0', '0', '0', '0']
# ['학원의설립운영및과외교습에관한법률', '검사지휘', '0', '0', '0', '1', '1']
# ['학원의설립운영및과외교습에관한법률', '타기관에서 이송', '0', '0', '1', '0', '0']
# ['학원의설립운영및과외교습에관한법률', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['학원의설립운영및과외교습에관한법률', '장물', '0', '0', '0', '0', '0']
# ['학원의설립운영및과외교습에관한법률', '전과조회', '0', '0', '0', '0', '0']
# ['학원의설립운영및과외교습에관한법률', '기타', '7', '8', '11', '11', '8']
# ['화물자동차운수사업법', '현행범', '11', '13', '7', '5', '1']
# ['화물자동차운수사업법', '피해자신고', '16', '16', '23', '13', '16']
# ['화물자동차운수사업법', '고소', '19', '22', '28', '27', '27']
# ['화물자동차운수사업법', '고발', '454', '567', '549', '545', '1867']
# ['화물자동차운수사업법', '자수', '1', '1', '0', '0', '0']
# ['화물자동차운수사업법', '민간체포', '0', '0', '0', '0', '0']
# ['화물자동차운수사업법', '진정투서', '107', '136', '232', '290', '201']
# ['화물자동차운수사업법', '타인신고', '696', '900', '1033', '898', '671']
# ['화물자동차운수사업법', '신문', '1', '0', '0', '0', '0']
# ['화물자동차운수사업법', '불심검문', '30', '43', '44', '10', '77']
# ['화물자동차운수사업법', '탐문정보', '14', '76', '156', '134', '74']
# ['화물자동차운수사업법', '안면식별', '0', '0', '0', '0', '0']
# ['화물자동차운수사업법', '감식자료', '0', '0', '0', '0', '0']
# ['화물자동차운수사업법', '변사체', '0', '0', '0', '0', '0']
# ['화물자동차운수사업법', '범죄수법', '0', '0', '0', '0', '0']
# ['화물자동차운수사업법', '발자국', '0', '0', '0', '0', '0']
# ['화물자동차운수사업법', '검사지휘', '0', '0', '1', '1', '2']
# ['화물자동차운수사업법', '타기관에서 이송', '1', '2', '9', '9', '5']
# ['화물자동차운수사업법', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['화물자동차운수사업법', '장물', '0', '0', '0', '0', '0']
# ['화물자동차운수사업법', '전과조회', '0', '0', '0', '0', '0']
# ['화물자동차운수사업법', '기타', '191', '310', '281', '337', '229']
# ['화재로인한재해보상과보험가입에관한법률', '현행범', '0', '0', '0', '0', '0']
# ['화재로인한재해보상과보험가입에관한법률', '피해자신고', '0', '0', '0', '0', '0']
# ['화재로인한재해보상과보험가입에관한법률', '고소', '0', '0', '0', '0', '0']
# ['화재로인한재해보상과보험가입에관한법률', '고발', '0', '0', '1', '0', '17']
# ['화재로인한재해보상과보험가입에관한법률', '자수', '0', '0', '0', '0', '0']
# ['화재로인한재해보상과보험가입에관한법률', '민간체포', '0', '0', '0', '0', '0']
# ['화재로인한재해보상과보험가입에관한법률', '진정투서', '0', '0', '0', '0', '0']
# ['화재로인한재해보상과보험가입에관한법률', '타인신고', '0', '0', '0', '0', '0']
# ['화재로인한재해보상과보험가입에관한법률', '신문', '0', '0', '0', '0', '0']
# ['화재로인한재해보상과보험가입에관한법률', '불심검문', '0', '0', '0', '0', '0']
# ['화재로인한재해보상과보험가입에관한법률', '탐문정보', '0', '0', '0', '0', '0']
# ['화재로인한재해보상과보험가입에관한법률', '안면식별', '0', '0', '0', '0', '0']
# ['화재로인한재해보상과보험가입에관한법률', '감식자료', '0', '0', '0', '0', '0']
# ['화재로인한재해보상과보험가입에관한법률', '변사체', '0', '0', '0', '0', '0']
# ['화재로인한재해보상과보험가입에관한법률', '범죄수법', '0', '0', '0', '0', '0']
# ['화재로인한재해보상과보험가입에관한법률', '발자국', '0', '0', '0', '0', '0']
# ['화재로인한재해보상과보험가입에관한법률', '검사지휘', '0', '0', '0', '0', '0']
# ['화재로인한재해보상과보험가입에관한법률', '타기관에서 이송', '0', '0', '0', '0', '0']
# ['화재로인한재해보상과보험가입에관한법률', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['화재로인한재해보상과보험가입에관한법률', '장물', '0', '0', '0', '0', '0']
# ['화재로인한재해보상과보험가입에관한법률', '전과조회', '0', '0', '0', '0', '0']
# ['화재로인한재해보상과보험가입에관한법률', '기타', '0', '0', '0', '0', '0']
# ['화재예방·소방시설설치유지및안전관리에관한법률', '현행범', '4', '1', '15', '13', '14']
# ['화재예방·소방시설설치유지및안전관리에관한법률', '피해자신고', '0', '0', '1', '1', '0']
# ['화재예방·소방시설설치유지및안전관리에관한법률', '고소', '1', '1', '2', '1', '0']
# ['화재예방·소방시설설치유지및안전관리에관한법률', '고발', '6', '2', '6', '20', '5']
# ['화재예방·소방시설설치유지및안전관리에관한법률', '자수', '1', '0', '1', '2', '0']
# ['화재예방·소방시설설치유지및안전관리에관한법률', '민간체포', '0', '0', '0', '0', '0']
# ['화재예방·소방시설설치유지및안전관리에관한법률', '진정투서', '0', '0', '0', '4', '5']
# ['화재예방·소방시설설치유지및안전관리에관한법률', '타인신고', '1', '0', '0', '0', '0']
# ['화재예방·소방시설설치유지및안전관리에관한법률', '신문', '1', '0', '4', '1', '0']
# ['화재예방·소방시설설치유지및안전관리에관한법률', '불심검문', '0', '0', '0', '0', '0']
# ['화재예방·소방시설설치유지및안전관리에관한법률', '탐문정보', '2', '0', '4', '7', '6']
# ['화재예방·소방시설설치유지및안전관리에관한법률', '안면식별', '0', '0', '0', '0', '0']
# ['화재예방·소방시설설치유지및안전관리에관한법률', '감식자료', '0', '0', '0', '0', '0']
# ['화재예방·소방시설설치유지및안전관리에관한법률', '변사체', '0', '0', '1', '0', '0']
# ['화재예방·소방시설설치유지및안전관리에관한법률', '범죄수법', '0', '0', '0', '0', '0']
# ['화재예방·소방시설설치유지및안전관리에관한법률', '발자국', '0', '0', '0', '0', '0']
# ['화재예방·소방시설설치유지및안전관리에관한법률', '검사지휘', '0', '0', '0', '0', '0']
# ['화재예방·소방시설설치유지및안전관리에관한법률', '타기관에서 이송', '0', '0', '0', '1', '3']
# ['화재예방·소방시설설치유지및안전관리에관한법률', '범행도구등 발견', '0', '0', '0', '0', '0']
# ['화재예방·소방시설설치유지및안전관리에관한법률', '장물', '0', '0', '0', '0', '0']
# ['화재예방·소방시설설치유지및안전관리에관한법률', '전과조회', '0', '0', '0', '0', '0']
# ['화재예방·소방시설설치유지및안전관리에관한법률', '기타', '158', '23', '350', '457', '359']
# ['화학물질관리법', '현행범', '163', '133', '108', '117', '94']
# ['화학물질관리법', '피해자신고', '11', '17', '9', '26', '16']
# ['화학물질관리법', '고소', '0', '2', '0', '1', '3']
# ['화학물질관리법', '고발', '20', '12', '9', '33', '113']
# ['화학물질관리법', '자수', '5', '4', '5', '11', '4']
# ['화학물질관리법', '민간체포', '0', '0', '0', '1', '0']
# ['화학물질관리법', '진정투서', '2', '1', '3', '16', '5']
# ['화학물질관리법', '타인신고', '98', '108', '89', '115', '97']
# ['화학물질관리법', '신문', '0', '0', '0', '1', '0']
# ['화학물질관리법', '불심검문', '1', '5', '1', '0', '2']
# ['화학물질관리법', '탐문정보', '47', '17', '18', '32', '11']
# ['화학물질관리법', '안면식별', '0', '0', '0', '0', '0']
# ['화학물질관리법', '감식자료', '1', '0', '0', '1', '0']
# ['화학물질관리법', '변사체', '0', '0', '0', '1', '0']
# ['화학물질관리법', '범죄수법', '0', '0', '0', '0', '0']
# ['화학물질관리법', '발자국', '0', '0', '0', '0', '0']
# ['화학물질관리법', '검사지휘', '0', '0', '0', '0', '2']
# ['화학물질관리법', '타기관에서 이송', '0', '2', '3', '4', '4']
# ['화학물질관리법', '범행도구등 발견', '0', '1', '1', '1', '3']
# ['화학물질관리법', '장물', '0', '0', '0', '0', '0']
# ['화학물질관리법', '전과조회', '0', '0', '0', '0', '0']
# ['화학물질관리법', '기타', '293', '381', '223', '267', '339']
# ['기타특별법', '현행범', '1329', '1204', '966', '949', '702']
# ['기타특별법', '피해자신고', '6540', '9493', '10488', '11133', '5279']
# ['기타특별법', '고소', '1597', '1519', '1683', '1964', '2102']
# ['기타특별법', '고발', '4959', '5845', '5923', '8020', '5804']
# ['기타특별법', '자수', '201', '306', '340', '394', '2597']
# ['기타특별법', '민간체포', '12', '2', '5', '10', '1']
# ['기타특별법', '진정투서', '1089', '994', '1105', '3154', '2282']
# ['기타특별법', '타인신고', '5776', '6313', '7061', '6529', '7746']
# ['기타특별법', '신문', '33', '123', '50', '51', '54']
# ['기타특별법', '불심검문', '2838', '2130', '2092', '1383', '3118']
# ['기타특별법', '탐문정보', '4572', '8988', '9805', '9500', '3396']
# ['기타특별법', '안면식별', '0', '2', '2', '2', '1']
# ['기타특별법', '감식자료', '0', '8', '8', '209', '0']
# ['기타특별법', '변사체', '3', '7', '7', '6', '2']
# ['기타특별법', '범죄수법', '3', '6', '4', '1', '5']
# ['기타특별법', '발자국', '0', '0', '0', '0', '0']
# ['기타특별법', '검사지휘', '46', '56', '69', '88', '106']
# ['기타특별법', '타기관에서 이송', '167', '114', '178', '426', '212']
# ['기타특별법', '범행도구등 발견', '11', '13', '1', '4', '2']
# ['기타특별법', '장물', '2', '3', '0', '0', '0']
# ['기타특별법', '전과조회', '5', '4', '4', '10', '5']
# ['기타특별법', '기타', '10053', '11442', '12641', '15551', '15854']

# %% [markdown]
# ### 3) 2016 - 2020 5년간 강력범죄(흉악) 검거 건수 평균 구하기 ###

# %%
# 필요한 라이브러리 import 
# csv : csv 파일을 읽어오기 위한 csv 라이브러리
# numpy : 배열 연산을 위한 numpy 라이브러리
# math : 소수점 결과를 내림하기 위한 math 라이브러리
import csv
import numpy as np
import math

# open() : 파일 열기 함수를 이용, csv 파일을 읽어온 후
# csv.reader() : 파일 객체의 csv 파일을 읽어 들이는 함수를 이용하여 읽는다.
f = open("범죄의 검거단서_전처리.csv")
crime = csv.reader(f)
# crime 데이터의 첫번째 줄은 title로 지정, next() 함수 : 행을 가져오고, 다음행으로 이동할 때 사용, "리스트"로 출력된다.
title = next(crime)
# 각 년도, 단서별로 나누어진 강력범죄 검거수 데이터를 하나로 합치기 위한 arrkill 리스트 정의
arrkill = []

# for문을 사용하여 crime 안에 있는
for i in crime:
    # index 0번째 데이터, 범죄별 항목이 '강력범죄(흉악)'일 경우,
    if(i[0] == '강력범죄(흉악)'):
        # 2016 ~ 2020년 (2번째 열~6번째 열)까지의 검거 수 데이터를
        for j in range(2,7):
            # 위에서 생성한 arrkill 리스트에 append()하여 넣어준다.
            arrkill.append(int(i[j]))
# 리스트에 담긴 흉악범죄 (2016년 ~ 2020년) 검거 수 데이터들의 모든 평균(mean)을 구해준 후, ceil을 이용하여 소수점 버리기. 
deadful_crime = math.ceil(np.mean(arrkill))

# 2016 - 2020 4년간 강력범죄(흉악) 검거 건수 평균 출력
print("2016년부터 2020년까지 연간 흉악범죄 검거 건수의 평균(건) : 약" , deadful_crime, "건")

# 파일닫기
f.close()
# Out:
# 2016년부터 2020년까지 연간 흉악범죄 검거 건수의 평균(건) : 약 1497 건

# %% [markdown]
# ### 4 - 1) 각 년도별 사기 범죄 검거 수의 총합 구하기. ###

# %%
# 필요한 라이브러리 import 
# csv : csv 파일을 읽어오기 위한 csv 라이브러리
# numpy : 배열 연산을 위한 numpy 라이브러리
import csv
import numpy as np

# open() : 파일 열기 함수를 이용, csv 파일을 읽어온 후
# csv.reader() : 파일 객체의 csv 파일을 읽어 들이는 함수를 이용하여 읽는다.
f = open("범죄의 검거단서_전처리.csv")
crime = csv.reader(f)
# crime 데이터의 첫번째 줄은 title로 지정, next() 함수 : 행을 가져오고, 다음행으로 이동할 때 사용, "리스트"로 출력된다.
title = next(crime)

# 각 년도별로 사기범죄 "검거 수"를 저장할 리스트 생성 (2016 ~ 2020)
trick2016 = []
trick2017 = []
trick2018 = []
trick2019 = []
trick2020 = []

# crime 데이터 안에
for i in crime:
    # index 0번째 데이터, 범죄별 항목이 '사기'일 경우,
    if(i[0] == '사기'):
        # 위에서 생성한 각 년도에 해당하는 리스트에 append()로 열을 기준으로 검거 수 데이터를 추가힌다.
        # 이때 sum 연산을 위해 값은 int형으로 받아온다.
        # 2번째 열 = 2016년, 3번째 열 = 2017년 ... 6번째 열 = 2020년
        trick2016.append(int(i[2]))
        trick2017.append(int(i[3]))
        trick2018.append(int(i[4]))
        trick2019.append(int(i[5]))
        trick2020.append(int(i[6]))
         
# 제목, 텍스트 출력 '\t'으로 구분
print("\t\t 각 년도별 사기 범죄자 검거 수(총합)\t\t")
print()
print("2016년 \t 2017년 \t 2018년 \t 2019년 \t 2020년")

# 위의 리스트에 저장한 값들을 numpy 라이브러리의 sum()함수를 이용하여,
# 각 년도별 리스트 안의 검거 수값들의 총합을 구한다.
print(np.sum(trick2016),"\t",np.sum(trick2017),"\t",np.sum(trick2018),"\t",np.sum(trick2019),"\t",np.sum(trick2020))

print(trick2016)
print(trick2017)
print(trick2018)
print(trick2019)
print(trick2020)
# Out:
# 		 각 년도별 사기 범죄자 검거 수(총합)
#
# 2016년 	 2017년 	 2018년 	 2019년 	 2020년
# 203236 	 190260 	 207927 	 230612 	 241133
# [7801, 19088, 88196, 798, 242, 6, 63780, 1567, 84, 263, 6875, 5, 54, 6, 49, 0, 512, 101, 26, 3, 76, 13704]
# [7248, 20459, 79924, 1135, 251, 14, 62773, 738, 30, 157, 5000, 10, 77, 16, 31, 1, 370, 80, 9, 5, 20, 11912]
# [6981, 26773, 84168, 1040, 266, 5, 69393, 807, 116, 184, 5037, 23, 70, 18, 23, 1, 648, 103, 2, 3, 24, 12242]
# [6688, 34978, 85372, 1337, 194, 14, 77221, 1472, 244, 119, 5014, 17, 109, 10, 45, 2, 695, 312, 6, 0, 51, 16712]
# [5763, 39549, 83940, 1513, 459, 20, 85116, 751, 223, 104, 6070, 16, 109, 43, 43, 0, 1314, 252, 6, 2, 57, 15783]

# %% [markdown]
# ### 4 - 2) 2016년부터 2020년까지 5년간 자수를 가장 많이 / 적게 한 범죄는? ###

# %%
# 필요한 라이브러리 import 
# csv : csv 파일을 읽어오기 위한 csv 라이브러리
# numpy : 배열 연산을 위한 numpy 라이브러리
import csv
import numpy as np

# open() : 파일 열기 함수를 이용, csv 파일을 읽어온 후
# csv.reader() : 파일 객체의 csv 파일을 읽어 들이는 함수를 이용하여 읽는다.
f = open("범죄의 검거단서_전처리.csv")
crime = csv.reader(f)


# list1 : "자수"로 검거한 범죄와 단서 정보를 저장하기 위한 리스트 
# find_max : 총 자수 횟수의 최대값을 찾기 위한 리스트
# find_min : 총 자수 횟수의 최소값을 찾기 위한 리스트
list1 = []
find_max = []
find_min = []

# 해당 데이터는 총 22개의 단서로 분류하고 있는데, 범죄 유형 첫번째는 범죄 유형이 아닌, "합계"이다.
# 이러한 합계 행은 최소/최대를 구하는 데에 방해가 될 수 있기 때문에 제외한다.
# next() 함수 : 행을 가져오고, 다음행으로 이동할 때 사용, "리스트"로 출력된다.
for t in range(22):
    next(crime)

    # crime 함수 안에
for i in crime:
    # 검거 단서가 자수일 경우
    if i[1] == '자수':
        # total : 2016년~2020년까지의 각 범죄별 "자수" 횟수의 합을 구하기 위한 변수, 0으로 초기화
        # if문에 해당하는 행의 2번째 ~ 6번째열 (2016년 ~ 2020년)에 해당하는 검거 수의 총 합을 구한다.
        total = 0
        for j in range(2,7):
            total+= int(i[j])
            
        # 위에서 계산한 총 합과 해당 행의 범죄(0번째 열), 검거단서(1번째 열)의 정보도 list1에 함께 저장한다.
        list1 .append(i[0])
        list1 .append(i[1])
        list1 .append(total)


# list1에는 자수에 해당하는 범죄, 단서, 5년간의 총합에 대한 3가지 유형의 데이터가 22번 들어있다.
# 해당 데이터를 범죄,단서,5년간의 총합 "3개씩" 분리하기 위해 차원을 재구성해주는 reshape() 함수를 사용했다.
# 먼저 리스트 형태의 list1을 np.array()를 사용하여 배열 형태로 만든 다음, 
# 행의 개수 = 전체데이터길이/3, 열의 개수 = 3개로 2차원 배열로 재구성하여 array 변수에 할당한다.
array = np.array(list1).reshape(int(len(list1)/3),3)

# 재구성한 2차원 배열에서 2번째 열(검거 수) 데이터를 각각의 최댓값/최솟값을 구하는 리스트에 추가한다.
for i in range(len(array)):
    find_max.append(int(array[i][2]))
    find_min.append(int(array[i][2]))

# 최대값을 구하는 리스트를 이용, 검거수의 최대값을 구하는 과정
maxValue = find_max[0]
for i in range(1, len(find_max)):
    if maxValue < find_max[i]:
        maxValue = find_max[i]

# 최소값을 구하는 리스트를 이용, 검거수의 최소값을 구하는 과정
minValue = find_min[0]
for i in range(1, len(find_min)):
    if minValue > find_min[i]:
        minValue = find_min[i]    

# array 2차원 배열에서 
# 검거 수(2번째 열)이 최대값과 일치할 경우 해당 열의 범죄유형(0번째 열)과 총 건수 출력
print("'자수'를 가장 많이 한 범죄 유형 :", maxValue, "건")    
for i in range(0,len(array)):        
    if array[i][2] == str(maxValue):
        print(array[i][0])

        
# 중간 공백으로 띄어쓰기
print("")     

# array 2차원 배열에서 
# 검거 수(2번째 열)이 최소값과 일치할 경우 해당 열의 범죄유형(0번째 열)과 총 건수 출력
print("'자수'를 가장 적게 한 범죄 유형 :", minValue, "건")
for i in range(0,len(array)):
    if array[i][2] == str(minValue):
        print(array[i][0])
# Out:
# '자수'를 가장 많이 한 범죄 유형 : 66271 건
# 특별법범
#
# '자수'를 가장 적게 한 범죄 유형 : 0 건
# 유가증권·인지·우표
# 비밀침해
# 내란의죄
# 음용수에관한죄
# 일수와수리에관한죄
# 개발제한구역의지정및관리에관한특별조치법
# 건강기능식품에관한법률
# 결혼중개업의관리에관한법률
# 공유재산및물품관리법
# 공직선거및선거부정방지법
# 관세법
# 국가기술자격법
# 낚시관리및육성법
# 농수산물유통및가격안정에관한법률
# 농지법
# 디자인보호법
# 배타적경제수역에서의외국인어업등에관한주권적권리의행사에관한법률
# 범죄수익은닉의규제및처벌등에관한법률
# 부정경쟁방지및영업비밀보호에관한법률
# 수도법
# 신용정보의이용및보호에관한법률
# 액화석유가스의안전관리및사업법
# 영유아보육법
# 전파법
# 특허법
# 학원의설립운영및과외교습에관한법률
# 화재로인한재해보상과보험가입에관한법률

# %% [markdown]
# ### 4 - 3) 가장 많은 저작권법위반을 검거한 단서 ###

# %%
# 필요한 라이브러리 import 
# csv : csv 파일을 읽어오기 위한 csv 라이브러리
# numpy : 배열 연산을 위한 numpy 라이브러리
import csv
import numpy as np

# open() : 파일 열기 함수를 이용, csv 파일을 읽어온 후
# csv.reader() : 파일 객체의 csv 파일을 읽어 들이는 함수를 이용하여 읽는다.
f = open("범죄의 검거단서_전처리.csv")
crime = csv.reader(f)

# list1 : 저작권법 위반 범죄에 해당하는 행의 정보 (단서, 검거수)를 저장하기 위한 리스트
# find_max : 최대값을 찾기 위한 리스트
list1 = []
find_max = []

# crime 데이터 안에
for i in crime:
    # 범죄명(0번째 열)이 '저작권법' 위반이라면,
    if i[0] == '저작권법':
        # total : 2016년~2020년까지의 각 범죄별 "저작권법" 위반 횟수의 합을 구하기 위한 변수, 0으로 초기화
        # 해당 행에 있는 2016년(2번째 열)~2020년(6번째 열)의 검거수를 모두 더한다.
        # 이때 열 값은 연산을 위해 int형으로 받아온다.
        total = 0
        for j in range(2,7):
            total+= int(i[j])
        # list1 리스트에 '저작권법'에 해당하는 (범죄단서)과 (5년간의 검거수 총합)을 추가한다.
        list1.append(i[1])
        list1.append(total)

# 출력 데이터가 들어있는 list1데이터에
for k in range(1, len(list1)):
    #  index 값이 홀수 (= 5년간의 검거수 총합)인 데이터들을
    if k % 2 == 1:
        # 최대값을 찾아주는 리스트에 추가한다.
        # 최대값을 찾아주는 리스트에 추가된 5년간의 검거수 총합 데이터들 중 가장 큰 값 maxValue변수에 넣는다.
        find_max.append(list1[k])
        
        maxValue = np.max(find_max)
# 출력 데이터가 들어있는 list1데이터에       
for k in range(1, len(list1)):
    # index 값이 홀수 (= 5년간의 검거수 총합)인 데이터들 중
    if k % 2 == 1:
        # maxValue값과 같은 값은
        if list1[k] == maxValue:
            # 가장 많은 저작권법 위반을 검거한 단서이다.
            print("가장 많은 저작권법 위반을 검거한 검거 단서는")
            print(list1[k-1],"->", maxValue, "건")
# Out:
# 가장 많은 저작권법 위반을 검거한 검거 단서는
# 고소 -> 28325 건

# %% [markdown]
# ### 6) 직선 그래프 출력 : 2016-2020 성폭력 범죄 검거단서별 검거수 ###

# %%
# 필요한 라이브러리 import 
# csv : csv 파일을 읽어오기 위한 csv 라이브러리
# numpy : 배열 연산을 위한 numpy 라이브러리
# matplotlib : 그래프를 그리기 위해 필요한 라이브러리
# %matplotlib inline 
import csv
import numpy as np
import matplotlib.pyplot as plt

# open() : 파일 열기 함수를 이용, csv 파일을 읽어온 후
# csv.reader() : 파일 객체의 csv 파일을 읽어 들이는 함수를 이용하여 읽는다.
f = open("범죄의 검거단서_전처리.csv")
crime = csv.reader(f)

# crime 데이터의 첫번째 줄은 title로 지정, next() 함수 : 행을 가져오고, 다음행으로 이동할 때 사용, "리스트"로 출력된다.
title = next(crime)

# 각 년도별로 성폭행죄 "검거 수"를 저장할 리스트 생성 (2016 ~ 2020)
array2016 = []
array2017 = []
array2018 = []
array2019 = []
array2020 = []

# clue : 22개의 검거 단서를 저장할 리스트
clue = [] 

# 읽어 온 crime 데이터 안에
for i in crime:
    # 범죄 유형이 성폭행인 행의
    if(i[0] == '성폭력'):
        # 2016~2020년의 검거수를 각 년도에 해당하는 리스트에 추가
        array2016.append(int(i[2]))
        array2017.append(int(i[3]))
        array2018.append(int(i[4]))
        array2019.append(int(i[5]))
        array2020.append(int(i[6]))
        
        # clue리스트에 22개의 검거단서 데이터 저장
        clue.append(i[1])
        
# 한글 글자깨짐 방지
plt.rcParams['font.family'] = 'NanumGothic'

# x 값은 각 검거단서 별 검거수, y값은 22개의 검거 단서 출력
# label : 범례표시
plt.plot(array2016, clue, label = "2016")
plt.plot(array2017, clue, label = "2017")
plt.plot(array2018, clue, label = "2018")
plt.plot(array2019, clue, label = "2019")
plt.plot(array2020, clue, label = "2020")

# x축 이름, y축 이름 생성
plt.xlabel('검거수')
plt.ylabel('검거단서')

# 오른쪽 상단에 범례 출력
plt.legend(loc="upper right")

# 그래프 제목 출력
plt.title("2016-2020 성폭력 검거단서별 검거수")

# 파일 닫기
f.close()
